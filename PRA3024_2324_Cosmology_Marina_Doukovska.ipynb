# %% [markdown]
# <a href="https://colab.research.google.com/github/marinaD10/PRA3024/blob/main/PRA3024_2324_Cosmology_Marina_Doukovska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='deepskyblue'>Cosmology MCMC notebook </font>

# %% [markdown]
# ## <font color='deepskyblue'>Preliminaries</font>

# %%
# Install required packages (if not available on server)
try:
  import getdist
except:
  # !pip install getdist
  import getdist

# Load required packages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.integrate as integrate

# import pylab
import getdist, IPython, time
from numpy import random

# from IPython.display import Image
from getdist import plots, MCSamples, loadMCSamples

# just for printing! calculations should be performed with machine precision
# %precision 3
# Out:
# Collecting getdist
#   Downloading getdist-1.4.7.tar.gz (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.1/826.1 kB 11.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from getdist) (1.25.2)
# Requirement already satisfied: matplotlib!=3.5.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from getdist) (3.7.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from getdist) (1.11.4)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from getdist) (6.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from getdist) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.5.0,>=2.2.0->getdist) (1.16.0)
# Building wheels for collected packages: getdist
#   Building wheel for getdist (pyproject.toml) ... done
#   Created wheel for getdist: filename=getdist-1.4.7-py3-none-any.whl size=810432 sha256=b1803e2c39a770d8732abc108e36fc56036dc0ba1f91ac0847080d89867726ef
#   Stored in directory: /root/.cache/pip/wheels/11/3e/8d/93c9494b4587d95165f805b376a4c7ed3ae670eb3cf7397389
# Successfully built getdist
# Installing collected packages: getdist
# Successfully installed getdist-1.4.7
# '%.3f'

# %% [markdown]
# <font color='tomato'>
# (NB: The equations you'll directly need to build your code are those $\boxed{\text{with a box around}}$)
# </font>
#
# ## <font color='deepskyblue'>The $\Lambda$CDM Model</font>
#
# The Lambda-Cold-Dark-Matter ($\Lambda$CDM) Model is our concordance cosmological model. It postulates a Universe that behaves according to **General Relativity**, filled with **baryons** (protons, neutrons - the stuff we and stars are made of!), **Cold Dark Matter (CDM)** and a **Cosmological Constant** $\Lambda$.
#
# The expansion of the Universe is best described in terms of the **scale factor** $a$ (the "radius" of the Universe, conventionally set to 1 today) and the **Hubble rate** $H$. While photons (light rays) travel in the expanding universe they get redshifted, and this redshift is directly related to the size of the Universe when the photon was emitted compared to today:
#
# $$ \frac{\lambda_{\rm obs}}{\lambda_{\rm em}} \equiv 1 + z_{\rm em} = \frac{1}{a_{\rm em}}$$
#
#
# In the $\Lambda$CDM model (and at late enough times), this additionally simplifies to
#
# $$
# \begin{gathered}
# \boxed{
# H^2 = H_0^2\left[\Omega_\Lambda + \Omega_m (1+z)^3 + \Omega_k (1+z)^2\right]
# }
# \\
# \boxed{
# \Omega_m + \Omega_\Lambda + \Omega_k = 1
# }
# \end{gathered}
# \tag{1}
# $$
#
# $H_0$ is the value of the Hubble rate *today*, and the parameters $\Omega_m$, $\Omega_\Lambda$ and $\Omega_k$ are dimensionless quantities indicating how much of the present expansion of the Universe is due to (non-relativistic) matter, cosmological constant $\Lambda$, and spatial curvature $k$. Note that the three $\Omega$'s are *not independent* (their sum is 1) and that we grouped together the contribution of baryons and CDM,
#
# $$
# \Omega_m = \Omega_{\rm CDM} + \Omega_{\rm b}
# $$
#
# and that we have evidence that independent evidence that $\Omega_b \approx 5$\%. NB: only $\Omega_m \geq 0$ makes physical sense, while in principle both $\Omega_\Lambda$ and $\Omega_k$ can be negative.
#
# The present Hubble rate is conventionally parametrised in terms of the dimensionless $h$:
#
# $$
# \boxed{
#   H_0 \equiv 100\,h\,\frac{\rm km}{\rm s\,Mpc}
# }
# \tag{2}
# $$
#
# where Mpc = Megaparsec and [parsec](https://en.wikipedia.org/wiki/Parsec) equals to about $3.26$ light years or $3.086 \cdot 10^{16}$ m.
#
# In essence, these equations give us the relation between *what exists in the Universe* and *how the Universe expanded*. Measure one, I can tell you the other. This is precisely what we aim to do!
#
# Time to define the function $H(z)$. Don't forget to include the useful parameters as arguments of the function, and to define `parsec`.

# %%
# Hubble rate: look at equations (1) and (2) for the definition!
def Hubble(z, OmegaL, OmegaM, H0):
  OmegaK = 1. - OmegaL - OmegaM
  H = H0 * np.sqrt(OmegaL + OmegaM * (1+z)**3 + OmegaK * (1+z)**2)
  return H

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
OmegaL = 0.7
OmegaM = 0.3
H0 = 0.7

zs = np.arange(0,1.4,0.1)
Hs = []
for z in zs:
  Hs += [Hubble(z, OmegaL, OmegaM, H0)]

plt.scatter(zs, Hs)
plt.xlabel('x')
plt.ylabel('H(z)')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>Supernovae Ia</font>
#
# In order to track the expansion of the Universe, we will look at Supernovae type Ia observations. SNIa are formed when a *white dwarf* accretes matter from a companion until it reaches a critical mass of about $1.44 M_\odot$ (solar masses), after which it explodes **at always the same luminosity** $L_{\rm SN}$. Therefore, the observed [magnitude](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) is only a function of their [**luminosity distance**](https://en.wikipedia.org/wiki/Distance_measures_(cosmology)) from Earth, defined as the ratio of the intrinsic luminosity $L_{\rm SNIa}$ and the measured *surface brightness* $\Phi$ (energy per unit time per unit area)
#
# $$ d_L\equiv \frac{L_{\rm SN}}{4\pi \Phi} $$
#
# We can express the luminosity distance in terms of the Hubble rate:
#
# $$
# \boxed{
# d_L(z) = \frac{c}{H_0}(1+z) \times
# \begin{cases}
#     \cfrac{1}{\sqrt{\Omega_k}} \,\sinh\left(\sqrt{\Omega_k}\,D(z)\right) & \Omega_k > 0
#     \\[.5em]
#     D(z) & \Omega_k = 0
#     \\[.5em]
#     \cfrac{1}{\sqrt{-\Omega_k}} \,\sin\left(\sqrt{-\Omega_k}\,D(z)\right) & \Omega_k < 0
# \end{cases}
# \qquad\qquad
# D(z) \equiv H_0\int_0^z \frac{{\rm d}Z}{H(Z)}
# }
# \tag{3}
# $$
#
# where $c$ is the speed of light: $c \simeq 2.998 \cdot 10^{5}$ km/s.
#
# Clearly, there exists a relation between $d_L(z)$ and $H(z)$, so the luminosity distance is a useful measure of the Universe expansion history.
# In practice, however, the actual observable for [Supernovae Type Ia](https://en.wikipedia.org/wiki/Type_Ia_supernova) (or SNIa) is the [distance modulus](https://en.wikipedia.org/wiki/Distance_modulus) $\mu$, defined as the difference between the *apparent magnitude* $m$ and the *absolute magnitude* $M$:
#
# $$
# \boxed{
# \mu(z) \equiv m(z) - M \equiv 5 \log_{10} \frac{d_L(z)}{10\,\text{pc}}
# }
# \tag{4}
# $$
#
# We can create the function `dL(z, h, Omega_m, Omega_Lambda)`. You can also pass the function `Hubble` as an argument: `dL(z, Hubble, Omega_m, Omega_Lambda)`. Additionally, you can create $D(z)$ for your convenience.
#
# Note that you need to integrate the function $H(z)$, so write your own quick-and-easy numerical integrator, for example implementing the [trapezoidal rule](https://en.wikipedia.org/wiki/Trapezoidal_rule) or your favourite alternative, or [look up the pre-written methods](https://docs.scipy.org/doc/scipy/tutorial/integrate.html). Make sure it returns $d_L$ in parsecs and that it uses $H_0$ measured in units of 100 km/s/Mpc (which we called $h$).

# %%
import numpy as np
from scipy import integrate, constants
SPEED_OF_LIGHT = 2.998e5

# Integrate 1/H from x = 0 to x = z
def D(z, OmegaL, OmegaM, H0): # Yes, you can pass a function as argument!
    return H0 * integrate.quad(lambda x: 1/Hubble(x, OmegaL, OmegaM, H0), 0, z)[0]
    # This is how you integrate with integrate.quad;
    # (...)[0] gives the result of the integral; (...)[1] is the error estimate; see manual for details

def dL(z, OmegaM, OmegaL, H0): # luminosity distance, use eq.(3)
    OmegaK = 1. - OmegaL - OmegaM
    Dz = D(z, OmegaL, OmegaM, H0)

    if(OmegaK > 0) :
        dL = 1/np.sqrt(OmegaK) * np.sinh(np.sqrt(OmegaK) * Dz)
    if(OmegaK ==0) :
        dL = Dz
    if(OmegaK < 0) :
        dL = 1/np.sqrt(-OmegaK) * np.sin(np.sqrt(-OmegaK) * Dz)

    dL = 10.**4* SPEED_OF_LIGHT/H0*(1+z)*dL
    return dL

# %%
# Define cosmological parameters
OmegaM = 0.3
OmegaL = 0.7
OmegaK = 1 - OmegaM - OmegaL  # Ensure OmegaK + OmegaM + OmegaL = 1 for a flat universe
H0 = 0.7  # Hubble constant parameter

# Redshift
zs = np.arange(0, 1.4, 0.1)
dLs = []
for z in zs:
    dLs.append(dL(z, OmegaL, OmegaM, H0))

# Calculate distance modulus
#mus = [mu(z, dL) for z, dL in zip(zs, dLs)]

plt.scatter(zs, dLs)
plt.xlabel('z')
plt.ylabel('dL(z)')
plt.show()

# %%
OmegaM = 0.3
OmegaL = 0.7
H0 = 0.7

zs = np.arange(0, 1.4, 0.1)
dLs = []
for z in zs:
    dLs.append(dL (z, OmegaL, OmegaM, H0))

plt.scatter(zs, dLs)
plt.xlabel('z')
plt.ylabel('dL(z)')
plt.show()

# %%
def mu(z, OmegaL, OmegaM, H0): # distance modulus -- use eq.(4)
    return 5 * np.log10( dL(z, OmegaL, OmegaM, H0) / 10 )

# %%
OmegaL = 0.7
OmegaM = 0.3
H0 = 0.7

zs = np.arange(0.1, 1.7, 0.1)
mus = []
for z in zs :
    mus += [mu(z, OmegaL, OmegaM, H0)]

plt.scatter(zs, mus, marker='D')
plt.xlabel('z')
plt.ylabel('${\mu}$(z)')
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>The Union2.1 Compilation</font>
#
# Our source of data is from [Union2.1](http://supernova.lbl.gov/Union/). It is a collection of $580$ SNIa, each observation is comprised of redshift $z$
# Our goal today is to use SNIa measurements to constrain the parameters ($h, \Omega_\Lambda, \Omega_m$).
#
# In essence, we can calculate for each redshift the theoretical value of $\mu$ using this equation with the expression for $d_L(z)$ and our model of choice $H(z)$ -- note that we will need to perform a numerical integral! -- and compare this value with observations. A different model would amount to changing the theoretical value of $H(z)$.
#
# Let us start by importing and plotting the data:

# %%
dataloc = "http://supernova.lbl.gov/Union/figures/SCPUnion2.1_mu_vs_z.txt"

# Read in data as numpy array.
# Format is [name, redshift, magnitude, magnitude error, and another number?]
data = np.genfromtxt(dataloc)

# Print the first line as an example. (Note that genfromtxt turns the names into 'Not A Number')
display(data[0])
# Out:
# array([      nan, 2.849e-02, 3.535e+01, 2.239e-01, 1.284e-01])

# %%
# Extract the redshifts (zs), distance modulus (dist_mod) and magnitude estimated errors (err_dist_mod)
# Data are in columns, so we either slice it by columns: arr[:,n]...
zs = data[:,1] # redshift

# ...or transpose the array and then slice by row: arr_transposed[n]
distance_modulus = data.T[2] # distance modulus
error_distance_modulus = data.T[3] # errors on distance modulus = sigmas

# %%
# Let's look at the data, just for fun.
# We can look both at the raw data (distance modulus) or calculate the luminosity distance
# Note that Numpy allows us to manipulate whole arrays at once with something like:
#     array_2 = some_function_of(array_1)

# luminosity distance in pc
luminosity_distance_pc = 10. * 10.**(distance_modulus / 5.)

# and in Mpc
luminosity_distance_Mpc = luminosity_distance_pc / 10.**6

# and the error on that distance:
error_luminosity_distance_Mpc = 5. * (10.**((distance_modulus + error_distance_modulus)/5.-6.) - 10.**((distance_modulus - error_distance_modulus)/5.-6.))

# %%
# Recommendation: you might want to try your functions here, and check that for Omega_m = 0.3 and Omega_L = 0.7 you get a decent match to the data
# %matplotlib inline
plt.subplots(1, 2, figsize=(12, 4))
# Plot distance modulus versus redshift (original data)
plt.subplot(1,2,1)
plt.xlabel("Redshift")
plt.ylabel("Distance modulus")
sorted_data = data[data[:,1].argsort()]
plt.plot(sorted_data[:,1], sorted_data[:,2])
plt.errorbar(zs,distance_modulus,yerr=data[:,3],fmt='o', markersize = '5', color ='k', ecolor='g')

plt.subplot(1, 2, 2)
plt.xlabel("Redshift")
plt.ylabel("Luminosity Distance [Mpc]")
plt.errorbar(zs, luminosity_distance_Mpc,\
             yerr=error_luminosity_distance_Mpc,\
             fmt='o',\
             color='black',\
             ecolor='darkcyan',\
             markersize=4)

plt.show()

# %%
plt.errorbar(zs, distance_modulus,\
             yerr=error_distance_modulus,\
             fmt='o',\
             color='black',\
             ecolor='red',\
             markersize=2)


OmegaL = 0.7
OmegaM = 0.3
H0     = 0.7 #0.7

modelzs = np.arange(0.05, 1.5, 0.05)
modelmus = []
for z in modelzs :
    modelmus += [mu(z, OmegaL, OmegaM, H0)]

plt.plot(modelzs, modelmus, linewidth=4)
plt.show()

# %% [markdown]
# ## <font color='deepskyblue'>Bayes' Theorem: Likelihood, Prior, Posterior (and Evidence...)</font>
#
# The **conditional probability of A given that B is true** is denoted with $P(A|B)$ (read: *probability of A given B*).
# Did A happen? Then B has probability $P(B|A)$ of happening.
#
# [**Bayes' Theorem**](https://en.wikipedia.org/wiki/Bayes%27_theorem) is simply a reflection of the symmetry of the concept of joint probability:
#
# $$
# P(A|B)P(B) = P(B|A)P(A)
# $$
#
# In physics, our goal is often to determine how likely the values of some parameters $\theta$ are, given how well they reproduce the data $D$.
# We write Bayes' theorem in the following equivalent form:
#
# $$
# P(\theta | D) = \frac{P(D|\theta)P(\theta)}{P(D)}
# $$
#
# The various terms conventionally take the names:
#
# $$
# \begin{aligned}
# P(\theta | D) & && \text{Posterior}
# \\
# P(D | \theta)& && \text{Likelihood}
# \\
# P(\theta) & && \text{Prior}
# \\
# P(D) & && \text{Evidence}
# \end{aligned}
# $$
#
# ### <font color='deepskyblue'>Prior</font>
#
# The *prior* quantifies our degree of prior belief in the model parameters. It can contain the results of previous experiments, or theoretical considerations (for instance, that certain parameters cannot be negative, etc.).
#
# We can have *strong priors* about something - the Sun still existing at night, see the comic below - or not.
# When we do *not* have compelling prior knowledge about a parameter, we generally use a *non-informative* prior probability distribution, most often related to the [uniform distribution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution)
#
# $$
# \begin{aligned}
#     \text{Uniform} & && \theta \in \text{Uniform}[\theta_{\rm min}, \theta_{\rm max}]
#     \\
#     \text{Log Uniform} & && \log\theta \in \text{Uniform}[\log\theta_{\rm min}, \log\theta_{\rm max}]
# \end{aligned}
# $$
#
# You may sometimes hear that "the prior doesn't matter". While this is not strictly true, it is however true that in many instances the *likelihood* depends more dramatically on the parameters and will have a dominating contribution to the posterior. You are more than welcome to try different priors for the model parameters and see if and how your results change.
#
# ### <font color='deepskyblue'>Likelihood</font>
#
# The measure of how well our model reproduces the data is the **likelihood** $\mathcal L$. For normal (=Gaussian), uncorrelated data $\mu_i$ with errors $\sigma_i$ ($i = \{1,580\}$), the likelihood is related to the famous [**chi-squared**](https://en.wikipedia.org/wiki/Chi-square_distribution) via
#
# $$
# P(D | \theta) \equiv \mathcal L = \exp\left(-\frac{\chi^2}{2}\right)
# \qquad
# \qquad
# \boxed{
# \chi^2 \equiv \sum_{i=1}^{580} \frac{\left(\mu_i^{(\rm theor)} - \mu_i^{(\rm obs)}\right)^2}{\sigma_i^2}
# }
# \tag{5}
# $$
#
# A *high likelihood* corresponds to a *low chi squared*.
#
# In principle, we could attack the problem brute-force: create a grid of values for $h$, $\Omega_m$, $\Omega_\Lambda$, calculate the likelihood for each combination, and create a profile for the likelihood.
#
# In practical cases, however, this is not only sub-optimal but sometimes **impossible**. Think of complicated models with 20+ free parameters (this is not unheard of, by the way). Even a very coarse grained grid of 100 values for each parameter would result in more than $10^{40}$ (!!!) different parameter combination to be tested. You can probably understand why this is undesirable.
#
# ### <font color='deepskyblue'>Evidence</font>
#
# This is the tricky bit. The evidence, which is "*the probability of observing certain data*", is not something that is easy to evaluate or interpret. This looks like a serious limitation to finding the:
#
#
# ### <font color='deepskyblue'>Posterior</font>
#
# What does the data tell us about the model parameters? The answer is the *posterior probability distribution*, often (but not necessarily) expressed as (average $\pm$ standard deviation)
#
# $$
# \theta_i = \bar\theta_i \pm \sigma_i
# $$
#
# In other words, the posterior tells us how likely it is for the model parameters to have certain values, *given that we observe the data* $D$.
#
# *This is the final goal of our analysis!*
#
# <br>
#
# ![title](http://1.bp.blogspot.com/-tTx4HDejSww/ULcTeK9_V_I/AAAAAAAAA8g/PCYOH-eXGbk/s1600/frequentists_vs_bayesians.png)
# ![title](https://i.redd.it/5r0hwixt0m931.jpg)

# %% [markdown]
# ## <font color='deepskyblue'>Markov-Chain Monte Carlo</font>
#
# Markov-Chain Monte Carlo techniques are a class of methods to sample a probability distribution $P(x)$ - in our case $P(\theta | D)$ - provided that we can calculate a density $\mathcal F(x)$ **that is proportional to it** - in our case $P(\theta)P(D|\theta)$ = likelihood $\times$ prior. Among these, a very popular one is the [**Metropolis-Hastings**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) algorithm, which is what we will use.
#
# Schematically, the algorithm works as follows:
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and calculate the $\mathcal F_{\rm old}$
# * Propose a new set of parameters $\theta_{\rm prop}$, calculate the new corresponding $\mathcal F_{\rm prop}$. How you propose the new parameters is not essential as long as the probability of going from one set of parameters to the next is the same as the inverse: $P(\theta_a \to \theta_b) = P(\theta_b \to \theta_a)$. For this, we normally take Gaussian displacements with some (relatively small) standard deviation.
# * Compare the new and old likelihoods-priors:
#     * If $\mathcal F_{\rm prop} > \mathcal F_{\rm old}$, accept the step: $\theta_{\rm new} = \theta_{\rm prop}$
#     * Otherwise, accept with probability $P_{\rm accept} = \mathcal F_{\rm prop}/\mathcal F_{\rm old}$
# * If accepted, $\theta_{\rm new} = \theta_{\rm prop}$ and record the step; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Update $\theta_{\rm old} = \theta_{\rm new}$
# * Repeat
#
# The MC chain keeps going until the desired number of steps or, ideally, when a suitable convergence test, like for example the [Gelman-Rubin test](https://bookdown.org/rdpeng/advstatcomp/monitoring-convergence.html), is satisfied.
# Today we will just set a limit to the total number of steps, but please feel free to implement and test your favourite convergence test!
#
# Looking at equation (5), you can convince yourself that
# $$
# \frac{\mathcal L_a}{\mathcal L_b} = \exp\left(\frac{\chi_b^2 - \chi_a^2}{2}\right)
# $$
#
# (This is useful because $\chi^2$ can be large, so we want to avoid the likelihoods evaluating to `0.` -- computers don't like dividing by zero, unfortunately)
#
#
# * <font color="deepskyblue"> Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and the corresponding chi squared $\chi_{\rm old}^2$ (to be clear, for us this implies calculating a series of 580 integrals and comparing each with the observed values) </font>
# * <font color="deepskyblue"> Propose new parameters $\theta_{\rm prop}$ and calculate the corresponding chi squared $\chi_{\rm prop}^2$</font>
# * <font color="deepskyblue"> Draw a random number $r \in [0,1]$</font>
# * <font color="deepskyblue"> Accept the step if
# $$
# r < \exp\left(\frac{\chi_{\rm old}^2 - \chi_{\rm prop}^2}{2}\right) \frac{P(\theta)_{\rm prop}}{P(\theta)_{\rm old}}
# $$</font>
#     * <font color="deepskyblue"> If accepted, update $\theta_{\rm old} = \theta_{\rm prop}$</font>
#     * <font color="deepskyblue">If you want, you can keep a record of the best fit (lowest $\chi^2$), but this is not the specific purpose of MCMC! We are exploring the parameter space and sampling a _posterior distribution_, not just finding the best fit</font>
# * <font color="deepskyblue"> Record the step - including **re-recording** if the step was not accepted! </font>
# * <font color="deepskyblue"> Repeat</font>

# %%
# Defining ChiSquared function
function = np.vectorize(mu)
def chi_squared(Omega_L, Omega_M, H0):
    chiSquared = 0
    for j in range(len(zs)):

      chiSquared += ((mu(zs[j],Omega_L, Omega_M, H0) - (distance_modulus[j]))**2)/(error_distance_modulus[j]**2)

    return chiSquared

# %%
from math import exp
from numpy import random
from random import gauss

filename = "Markov-Chain.txt"
file = open(filename, "w")

N_steps = 5000

Omega_M_old = 0.1
Omega_L_old = 0.1
H0_old = 0.1

Omega_M_list = []
Omega_L_list = []
H0_list = []
chiSquared_list = []

for i in range(N_steps):
  chi_squared_old = chi_squared(Omega_L_old, Omega_M_old, H0_old)
  Omega_M_new = Omega_M_old + np.random.normal(0,0.01)
  Omega_L_new = Omega_L_old + np.random.normal(0,0.01)
  H0_new = H0_old + np.random.normal(0,0.01)
  print("Omega_M = " + str(round(Omega_M_old,3)) + " , Omega_L = " + str(round(Omega_L_old,3)) + " , H0 = " + str(round(H0_old,3)))

  chi_squared_new = chi_squared(Omega_L_new, Omega_M_new, H0_new)


  if (chi_squared_new < chi_squared_old or np.random.uniform(0,1) < (np.exp((chi_squared_old-chi_squared_new)/2.0)).any()):
    print("Good step!")
    Omega_M_old = Omega_M_new
    Omega_L_old = Omega_L_new
    H0_old = H0_new
    chi_squared_old = chi_squared_new

    Omega_M_list += [Omega_L_old]
    Omega_L_list += [Omega_L_old]
    H0_list += [H0_old]
    chiSquared_list += [chi_squared_old]

  i+=1
  if i>500:
    print("OmegaM:" + str(round(Omega_M_old,4)) + " ; OmegaL:" + str(round(Omega_L_old,4)) + " ; h:" + str(round(H0_old,4)))

file.close();
# Out:
# Streaming output truncated to the last 5000 lines.
# Good step!
# OmegaM:-0.0744 ; OmegaL:-0.0738 ; h:0.801
# Omega_M = -0.074 , Omega_L = -0.074 , H0 = 0.801
# Good step!
# OmegaM:-0.0891 ; OmegaL:-0.0774 ; h:0.7886
# Omega_M = -0.089 , Omega_L = -0.077 , H0 = 0.789
# Good step!
# OmegaM:-0.0764 ; OmegaL:-0.07 ; h:0.7963
# Omega_M = -0.076 , Omega_L = -0.07 , H0 = 0.796
# Good step!
# OmegaM:-0.0861 ; OmegaL:-0.0865 ; h:0.8083
# Omega_M = -0.086 , Omega_L = -0.086 , H0 = 0.808
# Good step!
# OmegaM:-0.0941 ; OmegaL:-0.085 ; h:0.8121
# Omega_M = -0.094 , Omega_L = -0.085 , H0 = 0.812
# Good step!
# OmegaM:-0.086 ; OmegaL:-0.0891 ; h:0.8105
# Omega_M = -0.086 , Omega_L = -0.089 , H0 = 0.81
# Good step!
# OmegaM:-0.0996 ; OmegaL:-0.0991 ; h:0.7996
# Omega_M = -0.1 , Omega_L = -0.099 , H0 = 0.8
# Good step!
# OmegaM:-0.0994 ; OmegaL:-0.0883 ; h:0.8103
# Omega_M = -0.099 , Omega_L = -0.088 , H0 = 0.81
# Good step!
# OmegaM:-0.1012 ; OmegaL:-0.106 ; h:0.8001
# Omega_M = -0.101 , Omega_L = -0.106 , H0 = 0.8
# Good step!
# OmegaM:-0.0929 ; OmegaL:-0.0977 ; h:0.8149
# Omega_M = -0.093 , Omega_L = -0.098 , H0 = 0.815
# Good step!
# OmegaM:-0.0754 ; OmegaL:-0.0798 ; h:0.81
# Omega_M = -0.075 , Omega_L = -0.08 , H0 = 0.81
# Good step!
# OmegaM:-0.0785 ; OmegaL:-0.0805 ; h:0.821
# Omega_M = -0.078 , Omega_L = -0.08 , H0 = 0.821
# Good step!
# OmegaM:-0.0797 ; OmegaL:-0.0739 ; h:0.8011
# Omega_M = -0.08 , Omega_L = -0.074 , H0 = 0.801
# Good step!
# OmegaM:-0.0842 ; OmegaL:-0.0913 ; h:0.8033
# Omega_M = -0.084 , Omega_L = -0.091 , H0 = 0.803
# Good step!
# OmegaM:-0.0793 ; OmegaL:-0.1037 ; h:0.8173
# Omega_M = -0.079 , Omega_L = -0.104 , H0 = 0.817
# Good step!
# OmegaM:-0.0712 ; OmegaL:-0.0999 ; h:0.8033
# Omega_M = -0.071 , Omega_L = -0.1 , H0 = 0.803
# Good step!
# OmegaM:-0.0749 ; OmegaL:-0.119 ; h:0.8121
# Omega_M = -0.075 , Omega_L = -0.119 , H0 = 0.812
# Good step!
# OmegaM:-0.0851 ; OmegaL:-0.1281 ; h:0.8093
# Omega_M = -0.085 , Omega_L = -0.128 , H0 = 0.809
# Good step!
# OmegaM:-0.0809 ; OmegaL:-0.1387 ; h:0.802
# Omega_M = -0.081 , Omega_L = -0.139 , H0 = 0.802
# Good step!
# OmegaM:-0.096 ; OmegaL:-0.1384 ; h:0.7924
# Omega_M = -0.096 , Omega_L = -0.138 , H0 = 0.792
# Good step!
# OmegaM:-0.0829 ; OmegaL:-0.1315 ; h:0.7916
# Omega_M = -0.083 , Omega_L = -0.132 , H0 = 0.792
# Good step!
# OmegaM:-0.0859 ; OmegaL:-0.1157 ; h:0.8035
# Omega_M = -0.086 , Omega_L = -0.116 , H0 = 0.803
# Good step!
# OmegaM:-0.0761 ; OmegaL:-0.1196 ; h:0.818
# Omega_M = -0.076 , Omega_L = -0.12 , H0 = 0.818
# Good step!
# OmegaM:-0.0693 ; OmegaL:-0.1108 ; h:0.8131
# Omega_M = -0.069 , Omega_L = -0.111 , H0 = 0.813
# Good step!
# OmegaM:-0.0765 ; OmegaL:-0.1131 ; h:0.829
# Omega_M = -0.077 , Omega_L = -0.113 , H0 = 0.829
# Good step!
# OmegaM:-0.0588 ; OmegaL:-0.0996 ; h:0.8131
# Omega_M = -0.059 , Omega_L = -0.1 , H0 = 0.813
# Good step!
# OmegaM:-0.0593 ; OmegaL:-0.1108 ; h:0.8024
# Omega_M = -0.059 , Omega_L = -0.111 , H0 = 0.802
# Good step!
# OmegaM:-0.0372 ; OmegaL:-0.0957 ; h:0.8222
# Omega_M = -0.037 , Omega_L = -0.096 , H0 = 0.822
# Good step!
# OmegaM:-0.0484 ; OmegaL:-0.1054 ; h:0.8316
# Omega_M = -0.048 , Omega_L = -0.105 , H0 = 0.832
# Good step!
# OmegaM:-0.0657 ; OmegaL:-0.1096 ; h:0.8408
# Omega_M = -0.066 , Omega_L = -0.11 , H0 = 0.841
# Good step!
# OmegaM:-0.0639 ; OmegaL:-0.1071 ; h:0.8302
# Omega_M = -0.064 , Omega_L = -0.107 , H0 = 0.83
# Good step!
# OmegaM:-0.0631 ; OmegaL:-0.1204 ; h:0.8318
# Omega_M = -0.063 , Omega_L = -0.12 , H0 = 0.832
# Good step!
# OmegaM:-0.0707 ; OmegaL:-0.1092 ; h:0.8248
# Omega_M = -0.071 , Omega_L = -0.109 , H0 = 0.825
# Good step!
# OmegaM:-0.0596 ; OmegaL:-0.1038 ; h:0.8234
# Omega_M = -0.06 , Omega_L = -0.104 , H0 = 0.823
# Good step!
# OmegaM:-0.0672 ; OmegaL:-0.1029 ; h:0.8194
# Omega_M = -0.067 , Omega_L = -0.103 , H0 = 0.819
# Good step!
# OmegaM:-0.0579 ; OmegaL:-0.1138 ; h:0.825
# Omega_M = -0.058 , Omega_L = -0.114 , H0 = 0.825
# Good step!
# OmegaM:-0.0573 ; OmegaL:-0.1013 ; h:0.8218
# Omega_M = -0.057 , Omega_L = -0.101 , H0 = 0.822
# Good step!
# OmegaM:-0.0665 ; OmegaL:-0.099 ; h:0.8219
# Omega_M = -0.067 , Omega_L = -0.099 , H0 = 0.822
# Good step!
# OmegaM:-0.0477 ; OmegaL:-0.0956 ; h:0.825
# Omega_M = -0.048 , Omega_L = -0.096 , H0 = 0.825
# Good step!
# OmegaM:-0.0467 ; OmegaL:-0.1095 ; h:0.8147
# Omega_M = -0.047 , Omega_L = -0.11 , H0 = 0.815
# Good step!
# OmegaM:-0.061 ; OmegaL:-0.1007 ; h:0.8045
# Omega_M = -0.061 , Omega_L = -0.101 , H0 = 0.804
# Good step!
# OmegaM:-0.0616 ; OmegaL:-0.1044 ; h:0.8027
# Omega_M = -0.062 , Omega_L = -0.104 , H0 = 0.803
# Good step!
# OmegaM:-0.0552 ; OmegaL:-0.1 ; h:0.7985
# Omega_M = -0.055 , Omega_L = -0.1 , H0 = 0.799
# Good step!
# OmegaM:-0.0432 ; OmegaL:-0.1154 ; h:0.8112
# Omega_M = -0.043 , Omega_L = -0.115 , H0 = 0.811
# Good step!
# OmegaM:-0.0408 ; OmegaL:-0.1179 ; h:0.7941
# Omega_M = -0.041 , Omega_L = -0.118 , H0 = 0.794
# Good step!
# OmegaM:-0.0481 ; OmegaL:-0.1154 ; h:0.7858
# Omega_M = -0.048 , Omega_L = -0.115 , H0 = 0.786
# Good step!
# OmegaM:-0.0542 ; OmegaL:-0.1065 ; h:0.8036
# Omega_M = -0.054 , Omega_L = -0.107 , H0 = 0.804
# Good step!
# OmegaM:-0.0679 ; OmegaL:-0.111 ; h:0.8115
# Omega_M = -0.068 , Omega_L = -0.111 , H0 = 0.811
# Good step!
# OmegaM:-0.0705 ; OmegaL:-0.1192 ; h:0.801
# Omega_M = -0.07 , Omega_L = -0.119 , H0 = 0.801
# Good step!
# OmegaM:-0.0803 ; OmegaL:-0.1293 ; h:0.8045
# Omega_M = -0.08 , Omega_L = -0.129 , H0 = 0.804
# Good step!
# OmegaM:-0.0838 ; OmegaL:-0.1224 ; h:0.8069
# Omega_M = -0.084 , Omega_L = -0.122 , H0 = 0.807
# Good step!
# OmegaM:-0.0939 ; OmegaL:-0.1209 ; h:0.7896
# Omega_M = -0.094 , Omega_L = -0.121 , H0 = 0.79
# Good step!
# OmegaM:-0.0971 ; OmegaL:-0.129 ; h:0.7935
# Omega_M = -0.097 , Omega_L = -0.129 , H0 = 0.793
# Good step!
# OmegaM:-0.0937 ; OmegaL:-0.1216 ; h:0.7938
# Omega_M = -0.094 , Omega_L = -0.122 , H0 = 0.794
# Good step!
# OmegaM:-0.0913 ; OmegaL:-0.1129 ; h:0.8164
# Omega_M = -0.091 , Omega_L = -0.113 , H0 = 0.816
# Good step!
# OmegaM:-0.1221 ; OmegaL:-0.1045 ; h:0.8402
# Omega_M = -0.122 , Omega_L = -0.104 , H0 = 0.84
# Good step!
# OmegaM:-0.1122 ; OmegaL:-0.1092 ; h:0.837
# Omega_M = -0.112 , Omega_L = -0.109 , H0 = 0.837
# Good step!
# OmegaM:-0.1063 ; OmegaL:-0.1043 ; h:0.843
# Omega_M = -0.106 , Omega_L = -0.104 , H0 = 0.843
# Good step!
# OmegaM:-0.1103 ; OmegaL:-0.1255 ; h:0.8449
# Omega_M = -0.11 , Omega_L = -0.125 , H0 = 0.845
# Good step!
# OmegaM:-0.1177 ; OmegaL:-0.1239 ; h:0.8438
# Omega_M = -0.118 , Omega_L = -0.124 , H0 = 0.844
# Good step!
# OmegaM:-0.1186 ; OmegaL:-0.1274 ; h:0.8465
# Omega_M = -0.119 , Omega_L = -0.127 , H0 = 0.847
# Good step!
# OmegaM:-0.114 ; OmegaL:-0.1304 ; h:0.8502
# Omega_M = -0.114 , Omega_L = -0.13 , H0 = 0.85
# Good step!
# OmegaM:-0.1292 ; OmegaL:-0.1486 ; h:0.86
# Omega_M = -0.129 , Omega_L = -0.149 , H0 = 0.86
# Good step!
# OmegaM:-0.1347 ; OmegaL:-0.1362 ; h:0.8528
# Omega_M = -0.135 , Omega_L = -0.136 , H0 = 0.853
# Good step!
# OmegaM:-0.1354 ; OmegaL:-0.1391 ; h:0.8591
# Omega_M = -0.135 , Omega_L = -0.139 , H0 = 0.859
# Good step!
# OmegaM:-0.1357 ; OmegaL:-0.1257 ; h:0.8476
# Omega_M = -0.136 , Omega_L = -0.126 , H0 = 0.848
# Good step!
# OmegaM:-0.1414 ; OmegaL:-0.1171 ; h:0.8559
# Omega_M = -0.141 , Omega_L = -0.117 , H0 = 0.856
# Good step!
# OmegaM:-0.1354 ; OmegaL:-0.1129 ; h:0.8564
# Omega_M = -0.135 , Omega_L = -0.113 , H0 = 0.856
# Good step!
# OmegaM:-0.1444 ; OmegaL:-0.1047 ; h:0.858
# Omega_M = -0.144 , Omega_L = -0.105 , H0 = 0.858
# Good step!
# OmegaM:-0.1417 ; OmegaL:-0.0981 ; h:0.8592
# Omega_M = -0.142 , Omega_L = -0.098 , H0 = 0.859
# Good step!
# OmegaM:-0.1377 ; OmegaL:-0.1145 ; h:0.8783
# Omega_M = -0.138 , Omega_L = -0.115 , H0 = 0.878
# Good step!
# OmegaM:-0.1574 ; OmegaL:-0.1101 ; h:0.8836
# Omega_M = -0.157 , Omega_L = -0.11 , H0 = 0.884
# Good step!
# OmegaM:-0.157 ; OmegaL:-0.111 ; h:0.8979
# Omega_M = -0.157 , Omega_L = -0.111 , H0 = 0.898
# Good step!
# OmegaM:-0.1451 ; OmegaL:-0.1156 ; h:0.8944
# Omega_M = -0.145 , Omega_L = -0.116 , H0 = 0.894
# Good step!
# OmegaM:-0.1334 ; OmegaL:-0.1266 ; h:0.8948
# Omega_M = -0.133 , Omega_L = -0.127 , H0 = 0.895
# Good step!
# OmegaM:-0.1218 ; OmegaL:-0.1273 ; h:0.8954
# Omega_M = -0.122 , Omega_L = -0.127 , H0 = 0.895
# Good step!
# OmegaM:-0.1127 ; OmegaL:-0.1223 ; h:0.9027
# Omega_M = -0.113 , Omega_L = -0.122 , H0 = 0.903
# Good step!
# OmegaM:-0.1111 ; OmegaL:-0.1226 ; h:0.9011
# Omega_M = -0.111 , Omega_L = -0.123 , H0 = 0.901
# Good step!
# OmegaM:-0.1006 ; OmegaL:-0.1146 ; h:0.9064
# Omega_M = -0.101 , Omega_L = -0.115 , H0 = 0.906
# Good step!
# OmegaM:-0.0954 ; OmegaL:-0.1118 ; h:0.9267
# Omega_M = -0.095 , Omega_L = -0.112 , H0 = 0.927
# Good step!
# OmegaM:-0.0943 ; OmegaL:-0.1086 ; h:0.9284
# Omega_M = -0.094 , Omega_L = -0.109 , H0 = 0.928
# Good step!
# OmegaM:-0.0781 ; OmegaL:-0.1084 ; h:0.919
# Omega_M = -0.078 , Omega_L = -0.108 , H0 = 0.919
# Good step!
# OmegaM:-0.0781 ; OmegaL:-0.1237 ; h:0.9183
# Omega_M = -0.078 , Omega_L = -0.124 , H0 = 0.918
# Good step!
# OmegaM:-0.0583 ; OmegaL:-0.1265 ; h:0.9277
# Omega_M = -0.058 , Omega_L = -0.126 , H0 = 0.928
# Good step!
# OmegaM:-0.0541 ; OmegaL:-0.1164 ; h:0.9374
# Omega_M = -0.054 , Omega_L = -0.116 , H0 = 0.937
# OmegaM:-0.0541 ; OmegaL:-0.1164 ; h:0.9374
# Omega_M = -0.054 , Omega_L = -0.116 , H0 = 0.937
# Good step!
# OmegaM:-0.0566 ; OmegaL:-0.1173 ; h:0.9337
# Omega_M = -0.057 , Omega_L = -0.117 , H0 = 0.934
# Good step!
# OmegaM:-0.0705 ; OmegaL:-0.1414 ; h:0.9432
# Omega_M = -0.071 , Omega_L = -0.141 , H0 = 0.943
# Good step!
# OmegaM:-0.0665 ; OmegaL:-0.1401 ; h:0.9399
# Omega_M = -0.066 , Omega_L = -0.14 , H0 = 0.94
# Good step!
# OmegaM:-0.072 ; OmegaL:-0.1376 ; h:0.94
# Omega_M = -0.072 , Omega_L = -0.138 , H0 = 0.94
# Good step!
# OmegaM:-0.0872 ; OmegaL:-0.1303 ; h:0.9312
# Omega_M = -0.087 , Omega_L = -0.13 , H0 = 0.931
# Good step!
# OmegaM:-0.0707 ; OmegaL:-0.1249 ; h:0.9289
# Omega_M = -0.071 , Omega_L = -0.125 , H0 = 0.929
# Good step!
# OmegaM:-0.0636 ; OmegaL:-0.1178 ; h:0.922
# Omega_M = -0.064 , Omega_L = -0.118 , H0 = 0.922
# Good step!
# OmegaM:-0.0689 ; OmegaL:-0.1277 ; h:0.9129
# Omega_M = -0.069 , Omega_L = -0.128 , H0 = 0.913
# Good step!
# OmegaM:-0.0837 ; OmegaL:-0.1239 ; h:0.9026
# Omega_M = -0.084 , Omega_L = -0.124 , H0 = 0.903
# Good step!
# OmegaM:-0.0729 ; OmegaL:-0.129 ; h:0.912
# Omega_M = -0.073 , Omega_L = -0.129 , H0 = 0.912
# Good step!
# OmegaM:-0.083 ; OmegaL:-0.1234 ; h:0.9144
# Omega_M = -0.083 , Omega_L = -0.123 , H0 = 0.914
# Good step!
# OmegaM:-0.0751 ; OmegaL:-0.1197 ; h:0.9021
# Omega_M = -0.075 , Omega_L = -0.12 , H0 = 0.902
# Good step!
# OmegaM:-0.0732 ; OmegaL:-0.1164 ; h:0.8967
# Omega_M = -0.073 , Omega_L = -0.116 , H0 = 0.897
# Good step!
# OmegaM:-0.059 ; OmegaL:-0.1242 ; h:0.8881
# Omega_M = -0.059 , Omega_L = -0.124 , H0 = 0.888
# Good step!
# OmegaM:-0.0532 ; OmegaL:-0.1293 ; h:0.907
# Omega_M = -0.053 , Omega_L = -0.129 , H0 = 0.907
# Good step!
# OmegaM:-0.0552 ; OmegaL:-0.1367 ; h:0.8984
# Omega_M = -0.055 , Omega_L = -0.137 , H0 = 0.898
# Good step!
# OmegaM:-0.0488 ; OmegaL:-0.1298 ; h:0.8939
# Omega_M = -0.049 , Omega_L = -0.13 , H0 = 0.894
# Good step!
# OmegaM:-0.0585 ; OmegaL:-0.1483 ; h:0.8906
# Omega_M = -0.058 , Omega_L = -0.148 , H0 = 0.891
# Good step!
# OmegaM:-0.0533 ; OmegaL:-0.1447 ; h:0.8787
# Omega_M = -0.053 , Omega_L = -0.145 , H0 = 0.879
# Good step!
# OmegaM:-0.0422 ; OmegaL:-0.1477 ; h:0.8641
# Omega_M = -0.042 , Omega_L = -0.148 , H0 = 0.864
# Good step!
# OmegaM:-0.0309 ; OmegaL:-0.1279 ; h:0.8714
# Omega_M = -0.031 , Omega_L = -0.128 , H0 = 0.871
# Good step!
# OmegaM:-0.0333 ; OmegaL:-0.1313 ; h:0.8695
# Omega_M = -0.033 , Omega_L = -0.131 , H0 = 0.869
# Good step!
# OmegaM:-0.0242 ; OmegaL:-0.1332 ; h:0.8796
# Omega_M = -0.024 , Omega_L = -0.133 , H0 = 0.88
# Good step!
# OmegaM:-0.0162 ; OmegaL:-0.1325 ; h:0.8579
# Omega_M = -0.016 , Omega_L = -0.133 , H0 = 0.858
# Good step!
# OmegaM:-0.0247 ; OmegaL:-0.1237 ; h:0.8622
# Omega_M = -0.025 , Omega_L = -0.124 , H0 = 0.862
# Good step!
# OmegaM:-0.0188 ; OmegaL:-0.1134 ; h:0.8486
# Omega_M = -0.019 , Omega_L = -0.113 , H0 = 0.849
# Good step!
# OmegaM:-0.0244 ; OmegaL:-0.1101 ; h:0.8474
# Omega_M = -0.024 , Omega_L = -0.11 , H0 = 0.847
# Good step!
# OmegaM:-0.0249 ; OmegaL:-0.109 ; h:0.8399
# Omega_M = -0.025 , Omega_L = -0.109 , H0 = 0.84
# Good step!
# OmegaM:-0.0151 ; OmegaL:-0.1168 ; h:0.8476
# Omega_M = -0.015 , Omega_L = -0.117 , H0 = 0.848
# Good step!
# OmegaM:-0.0249 ; OmegaL:-0.1134 ; h:0.8463
# Omega_M = -0.025 , Omega_L = -0.113 , H0 = 0.846
# Good step!
# OmegaM:-0.0304 ; OmegaL:-0.1192 ; h:0.8306
# Omega_M = -0.03 , Omega_L = -0.119 , H0 = 0.831
# Good step!
# OmegaM:-0.031 ; OmegaL:-0.1174 ; h:0.8311
# Omega_M = -0.031 , Omega_L = -0.117 , H0 = 0.831
# Good step!
# OmegaM:-0.0204 ; OmegaL:-0.111 ; h:0.8246
# Omega_M = -0.02 , Omega_L = -0.111 , H0 = 0.825
# Good step!
# OmegaM:-0.0235 ; OmegaL:-0.1196 ; h:0.8149
# Omega_M = -0.024 , Omega_L = -0.12 , H0 = 0.815
# Good step!
# OmegaM:-0.0194 ; OmegaL:-0.1158 ; h:0.8182
# Omega_M = -0.019 , Omega_L = -0.116 , H0 = 0.818
# Good step!
# OmegaM:-0.0135 ; OmegaL:-0.1259 ; h:0.7992
# Omega_M = -0.014 , Omega_L = -0.126 , H0 = 0.799
# Good step!
# OmegaM:-0.0121 ; OmegaL:-0.1161 ; h:0.7916
# Omega_M = -0.012 , Omega_L = -0.116 , H0 = 0.792
# Good step!
# OmegaM:-0.0082 ; OmegaL:-0.1102 ; h:0.8084
# Omega_M = -0.008 , Omega_L = -0.11 , H0 = 0.808
# Good step!
# OmegaM:-0.0165 ; OmegaL:-0.1078 ; h:0.8087
# Omega_M = -0.017 , Omega_L = -0.108 , H0 = 0.809
# Good step!
# OmegaM:-0.0331 ; OmegaL:-0.1085 ; h:0.8094
# Omega_M = -0.033 , Omega_L = -0.109 , H0 = 0.809
# Good step!
# OmegaM:-0.0298 ; OmegaL:-0.1312 ; h:0.7985
# Omega_M = -0.03 , Omega_L = -0.131 , H0 = 0.799
# Good step!
# OmegaM:-0.0325 ; OmegaL:-0.1333 ; h:0.7944
# Omega_M = -0.033 , Omega_L = -0.133 , H0 = 0.794
# Good step!
# OmegaM:-0.0383 ; OmegaL:-0.1389 ; h:0.8107
# Omega_M = -0.038 , Omega_L = -0.139 , H0 = 0.811
# Good step!
# OmegaM:-0.0355 ; OmegaL:-0.1333 ; h:0.8209
# Omega_M = -0.036 , Omega_L = -0.133 , H0 = 0.821
# Good step!
# OmegaM:-0.0162 ; OmegaL:-0.1249 ; h:0.8198
# Omega_M = -0.016 , Omega_L = -0.125 , H0 = 0.82
# Good step!
# OmegaM:-0.0132 ; OmegaL:-0.1409 ; h:0.8277
# Omega_M = -0.013 , Omega_L = -0.141 , H0 = 0.828
# Good step!
# OmegaM:-0.0206 ; OmegaL:-0.1338 ; h:0.8295
# Omega_M = -0.021 , Omega_L = -0.134 , H0 = 0.829
# Good step!
# OmegaM:-0.0262 ; OmegaL:-0.1523 ; h:0.8167
# Omega_M = -0.026 , Omega_L = -0.152 , H0 = 0.817
# Good step!
# OmegaM:-0.0269 ; OmegaL:-0.158 ; h:0.8226
# Omega_M = -0.027 , Omega_L = -0.158 , H0 = 0.823
# Good step!
# OmegaM:-0.0253 ; OmegaL:-0.1504 ; h:0.8371
# Omega_M = -0.025 , Omega_L = -0.15 , H0 = 0.837
# Good step!
# OmegaM:-0.0058 ; OmegaL:-0.1279 ; h:0.8468
# Omega_M = -0.006 , Omega_L = -0.128 , H0 = 0.847
# Good step!
# OmegaM:-0.0114 ; OmegaL:-0.1316 ; h:0.849
# Omega_M = -0.011 , Omega_L = -0.132 , H0 = 0.849
# Good step!
# OmegaM:-0.004 ; OmegaL:-0.1271 ; h:0.8554
# Omega_M = -0.004 , Omega_L = -0.127 , H0 = 0.855
# Good step!
# OmegaM:-0.0172 ; OmegaL:-0.1154 ; h:0.8483
# Omega_M = -0.017 , Omega_L = -0.115 , H0 = 0.848
# Good step!
# OmegaM:-0.0233 ; OmegaL:-0.113 ; h:0.853
# Omega_M = -0.023 , Omega_L = -0.113 , H0 = 0.853
# Good step!
# OmegaM:-0.0228 ; OmegaL:-0.0974 ; h:0.8693
# Omega_M = -0.023 , Omega_L = -0.097 , H0 = 0.869
# Good step!
# OmegaM:-0.0244 ; OmegaL:-0.0836 ; h:0.8792
# Omega_M = -0.024 , Omega_L = -0.084 , H0 = 0.879
# Good step!
# OmegaM:-0.0107 ; OmegaL:-0.0731 ; h:0.8805
# Omega_M = -0.011 , Omega_L = -0.073 , H0 = 0.881
# Good step!
# OmegaM:-0.0037 ; OmegaL:-0.0708 ; h:0.8774
# Omega_M = -0.004 , Omega_L = -0.071 , H0 = 0.877
# Good step!
# OmegaM:0.0073 ; OmegaL:-0.08 ; h:0.8731
# Omega_M = 0.007 , Omega_L = -0.08 , H0 = 0.873
# Good step!
# OmegaM:-0.0001 ; OmegaL:-0.0889 ; h:0.8516
# Omega_M = -0.0 , Omega_L = -0.089 , H0 = 0.852
# Good step!
# OmegaM:0.0085 ; OmegaL:-0.081 ; h:0.8543
# Omega_M = 0.008 , Omega_L = -0.081 , H0 = 0.854
# Good step!
# OmegaM:0.0253 ; OmegaL:-0.0961 ; h:0.8674
# Omega_M = 0.025 , Omega_L = -0.096 , H0 = 0.867
# Good step!
# OmegaM:0.0199 ; OmegaL:-0.1003 ; h:0.8643
# Omega_M = 0.02 , Omega_L = -0.1 , H0 = 0.864
# Good step!
# OmegaM:0.0132 ; OmegaL:-0.1199 ; h:0.8635
# Omega_M = 0.013 , Omega_L = -0.12 , H0 = 0.864
# Good step!
# OmegaM:0.0088 ; OmegaL:-0.128 ; h:0.8578
# Omega_M = 0.009 , Omega_L = -0.128 , H0 = 0.858
# Good step!
# OmegaM:0.0182 ; OmegaL:-0.1466 ; h:0.8686
# Omega_M = 0.018 , Omega_L = -0.147 , H0 = 0.869
# Good step!
# OmegaM:0.0182 ; OmegaL:-0.1603 ; h:0.8709
# Omega_M = 0.018 , Omega_L = -0.16 , H0 = 0.871
# Good step!
# OmegaM:0.0289 ; OmegaL:-0.1566 ; h:0.8697
# Omega_M = 0.029 , Omega_L = -0.157 , H0 = 0.87
# Good step!
# OmegaM:0.0209 ; OmegaL:-0.1581 ; h:0.867
# Omega_M = 0.021 , Omega_L = -0.158 , H0 = 0.867
# Good step!
# OmegaM:0.0089 ; OmegaL:-0.16 ; h:0.8633
# Omega_M = 0.009 , Omega_L = -0.16 , H0 = 0.863
# Good step!
# OmegaM:0.0127 ; OmegaL:-0.1728 ; h:0.8616
# Omega_M = 0.013 , Omega_L = -0.173 , H0 = 0.862
# Good step!
# OmegaM:0.015 ; OmegaL:-0.1866 ; h:0.8537
# Omega_M = 0.015 , Omega_L = -0.187 , H0 = 0.854
# Good step!
# OmegaM:0.0233 ; OmegaL:-0.1833 ; h:0.8466
# Omega_M = 0.023 , Omega_L = -0.183 , H0 = 0.847
# Good step!
# OmegaM:0.0463 ; OmegaL:-0.1808 ; h:0.8367
# Omega_M = 0.046 , Omega_L = -0.181 , H0 = 0.837
# Good step!
# OmegaM:0.029 ; OmegaL:-0.1826 ; h:0.8325
# Omega_M = 0.029 , Omega_L = -0.183 , H0 = 0.832
# Good step!
# OmegaM:0.0218 ; OmegaL:-0.1909 ; h:0.8346
# Omega_M = 0.022 , Omega_L = -0.191 , H0 = 0.835
# Good step!
# OmegaM:0.004 ; OmegaL:-0.1974 ; h:0.8311
# Omega_M = 0.004 , Omega_L = -0.197 , H0 = 0.831
# Good step!
# OmegaM:0.0149 ; OmegaL:-0.1852 ; h:0.8274
# Omega_M = 0.015 , Omega_L = -0.185 , H0 = 0.827
# Good step!
# OmegaM:0.0234 ; OmegaL:-0.1869 ; h:0.838
# Omega_M = 0.023 , Omega_L = -0.187 , H0 = 0.838
# Good step!
# OmegaM:0.0127 ; OmegaL:-0.1745 ; h:0.8337
# Omega_M = 0.013 , Omega_L = -0.174 , H0 = 0.834
# Good step!
# OmegaM:0.0112 ; OmegaL:-0.1582 ; h:0.8226
# Omega_M = 0.011 , Omega_L = -0.158 , H0 = 0.823
# Good step!
# OmegaM:-0.0009 ; OmegaL:-0.1517 ; h:0.8214
# Omega_M = -0.001 , Omega_L = -0.152 , H0 = 0.821
# Good step!
# OmegaM:0.0079 ; OmegaL:-0.1515 ; h:0.8266
# Omega_M = 0.008 , Omega_L = -0.152 , H0 = 0.827
# Good step!
# OmegaM:0.0051 ; OmegaL:-0.1516 ; h:0.8245
# Omega_M = 0.005 , Omega_L = -0.152 , H0 = 0.825
# Good step!
# OmegaM:0.0147 ; OmegaL:-0.1299 ; h:0.8076
# Omega_M = 0.015 , Omega_L = -0.13 , H0 = 0.808
# Good step!
# OmegaM:0.0135 ; OmegaL:-0.1197 ; h:0.7994
# Omega_M = 0.013 , Omega_L = -0.12 , H0 = 0.799
# Good step!
# OmegaM:0.0029 ; OmegaL:-0.1091 ; h:0.8094
# Omega_M = 0.003 , Omega_L = -0.109 , H0 = 0.809
# Good step!
# OmegaM:-0.0146 ; OmegaL:-0.1225 ; h:0.8148
# Omega_M = -0.015 , Omega_L = -0.123 , H0 = 0.815
# Good step!
# OmegaM:-0.0204 ; OmegaL:-0.1179 ; h:0.8171
# Omega_M = -0.02 , Omega_L = -0.118 , H0 = 0.817
# Good step!
# OmegaM:-0.0325 ; OmegaL:-0.1157 ; h:0.8141
# Omega_M = -0.033 , Omega_L = -0.116 , H0 = 0.814
# Good step!
# OmegaM:-0.0153 ; OmegaL:-0.1056 ; h:0.8005
# Omega_M = -0.015 , Omega_L = -0.106 , H0 = 0.801
# Good step!
# OmegaM:-0.0124 ; OmegaL:-0.1247 ; h:0.7958
# Omega_M = -0.012 , Omega_L = -0.125 , H0 = 0.796
# Good step!
# OmegaM:-0.0061 ; OmegaL:-0.1464 ; h:0.8223
# Omega_M = -0.006 , Omega_L = -0.146 , H0 = 0.822
# Good step!
# OmegaM:-0.0023 ; OmegaL:-0.1575 ; h:0.8226
# Omega_M = -0.002 , Omega_L = -0.157 , H0 = 0.823
# Good step!
# OmegaM:0.0026 ; OmegaL:-0.1481 ; h:0.8264
# Omega_M = 0.003 , Omega_L = -0.148 , H0 = 0.826
# Good step!
# OmegaM:0.0092 ; OmegaL:-0.1403 ; h:0.8186
# Omega_M = 0.009 , Omega_L = -0.14 , H0 = 0.819
# Good step!
# OmegaM:-0.0004 ; OmegaL:-0.1649 ; h:0.8169
# Omega_M = -0.0 , Omega_L = -0.165 , H0 = 0.817
# Good step!
# OmegaM:-0.0113 ; OmegaL:-0.1729 ; h:0.8059
# Omega_M = -0.011 , Omega_L = -0.173 , H0 = 0.806
# Good step!
# OmegaM:-0.0179 ; OmegaL:-0.1781 ; h:0.7984
# Omega_M = -0.018 , Omega_L = -0.178 , H0 = 0.798
# Good step!
# OmegaM:-0.0062 ; OmegaL:-0.1761 ; h:0.791
# Omega_M = -0.006 , Omega_L = -0.176 , H0 = 0.791
# Good step!
# OmegaM:-0.0091 ; OmegaL:-0.1574 ; h:0.799
# Omega_M = -0.009 , Omega_L = -0.157 , H0 = 0.799
# Good step!
# OmegaM:-0.0111 ; OmegaL:-0.1617 ; h:0.8103
# Omega_M = -0.011 , Omega_L = -0.162 , H0 = 0.81
# Good step!
# OmegaM:-0.0015 ; OmegaL:-0.1503 ; h:0.8189
# Omega_M = -0.001 , Omega_L = -0.15 , H0 = 0.819
# Good step!
# OmegaM:0.0041 ; OmegaL:-0.118 ; h:0.8154
# Omega_M = 0.004 , Omega_L = -0.118 , H0 = 0.815
# Good step!
# OmegaM:0.0015 ; OmegaL:-0.1261 ; h:0.8127
# Omega_M = 0.001 , Omega_L = -0.126 , H0 = 0.813
# Good step!
# OmegaM:-0.0102 ; OmegaL:-0.1238 ; h:0.8152
# Omega_M = -0.01 , Omega_L = -0.124 , H0 = 0.815
# Good step!
# OmegaM:-0.0153 ; OmegaL:-0.1185 ; h:0.8324
# Omega_M = -0.015 , Omega_L = -0.118 , H0 = 0.832
# Good step!
# OmegaM:-0.022 ; OmegaL:-0.1166 ; h:0.833
# Omega_M = -0.022 , Omega_L = -0.117 , H0 = 0.833
# Good step!
# OmegaM:-0.0241 ; OmegaL:-0.0984 ; h:0.8253
# Omega_M = -0.024 , Omega_L = -0.098 , H0 = 0.825
# Good step!
# OmegaM:-0.0311 ; OmegaL:-0.0875 ; h:0.8212
# Omega_M = -0.031 , Omega_L = -0.088 , H0 = 0.821
# Good step!
# OmegaM:-0.0318 ; OmegaL:-0.0925 ; h:0.8302
# Omega_M = -0.032 , Omega_L = -0.092 , H0 = 0.83
# Good step!
# OmegaM:-0.0156 ; OmegaL:-0.0919 ; h:0.8432
# Omega_M = -0.016 , Omega_L = -0.092 , H0 = 0.843
# Good step!
# OmegaM:-0.0141 ; OmegaL:-0.0822 ; h:0.8613
# Omega_M = -0.014 , Omega_L = -0.082 , H0 = 0.861
# Good step!
# OmegaM:-0.0042 ; OmegaL:-0.1083 ; h:0.867
# Omega_M = -0.004 , Omega_L = -0.108 , H0 = 0.867
# Good step!
# OmegaM:-0.0065 ; OmegaL:-0.0992 ; h:0.8839
# Omega_M = -0.007 , Omega_L = -0.099 , H0 = 0.884
# Good step!
# OmegaM:-0.0026 ; OmegaL:-0.1029 ; h:0.8729
# Omega_M = -0.003 , Omega_L = -0.103 , H0 = 0.873
# Good step!
# OmegaM:-0.0058 ; OmegaL:-0.0903 ; h:0.8682
# Omega_M = -0.006 , Omega_L = -0.09 , H0 = 0.868
# Good step!
# OmegaM:-0.0073 ; OmegaL:-0.0935 ; h:0.8801
# Omega_M = -0.007 , Omega_L = -0.093 , H0 = 0.88
# Good step!
# OmegaM:-0.0023 ; OmegaL:-0.0904 ; h:0.8729
# Omega_M = -0.002 , Omega_L = -0.09 , H0 = 0.873
# Good step!
# OmegaM:0.005 ; OmegaL:-0.0945 ; h:0.869
# Omega_M = 0.005 , Omega_L = -0.095 , H0 = 0.869
# Good step!
# OmegaM:0.0206 ; OmegaL:-0.0863 ; h:0.8581
# Omega_M = 0.021 , Omega_L = -0.086 , H0 = 0.858
# Good step!
# OmegaM:0.0185 ; OmegaL:-0.0856 ; h:0.8571
# Omega_M = 0.019 , Omega_L = -0.086 , H0 = 0.857
# Good step!
# OmegaM:0.0157 ; OmegaL:-0.0641 ; h:0.8578
# Omega_M = 0.016 , Omega_L = -0.064 , H0 = 0.858
# Good step!
# OmegaM:0.0238 ; OmegaL:-0.0591 ; h:0.8754
# Omega_M = 0.024 , Omega_L = -0.059 , H0 = 0.875
# Good step!
# OmegaM:0.0376 ; OmegaL:-0.0607 ; h:0.8825
# Omega_M = 0.038 , Omega_L = -0.061 , H0 = 0.882
# Good step!
# OmegaM:0.0532 ; OmegaL:-0.0711 ; h:0.8778
# Omega_M = 0.053 , Omega_L = -0.071 , H0 = 0.878
# Good step!
# OmegaM:0.0546 ; OmegaL:-0.0712 ; h:0.8636
# Omega_M = 0.055 , Omega_L = -0.071 , H0 = 0.864
# Good step!
# OmegaM:0.0475 ; OmegaL:-0.0518 ; h:0.8497
# Omega_M = 0.048 , Omega_L = -0.052 , H0 = 0.85
# Good step!
# OmegaM:0.0654 ; OmegaL:-0.0732 ; h:0.8613
# Omega_M = 0.065 , Omega_L = -0.073 , H0 = 0.861
# Good step!
# OmegaM:0.0549 ; OmegaL:-0.0705 ; h:0.8566
# Omega_M = 0.055 , Omega_L = -0.07 , H0 = 0.857
# Good step!
# OmegaM:0.0614 ; OmegaL:-0.0864 ; h:0.8625
# Omega_M = 0.061 , Omega_L = -0.086 , H0 = 0.862
# Good step!
# OmegaM:0.0507 ; OmegaL:-0.0804 ; h:0.8631
# Omega_M = 0.051 , Omega_L = -0.08 , H0 = 0.863
# Good step!
# OmegaM:0.0437 ; OmegaL:-0.0792 ; h:0.8509
# Omega_M = 0.044 , Omega_L = -0.079 , H0 = 0.851
# Good step!
# OmegaM:0.0248 ; OmegaL:-0.0768 ; h:0.8451
# Omega_M = 0.025 , Omega_L = -0.077 , H0 = 0.845
# Good step!
# OmegaM:0.0249 ; OmegaL:-0.0915 ; h:0.8248
# Omega_M = 0.025 , Omega_L = -0.092 , H0 = 0.825
# Good step!
# OmegaM:0.0477 ; OmegaL:-0.0901 ; h:0.8165
# Omega_M = 0.048 , Omega_L = -0.09 , H0 = 0.816
# Good step!
# OmegaM:0.0527 ; OmegaL:-0.0855 ; h:0.8142
# Omega_M = 0.053 , Omega_L = -0.085 , H0 = 0.814
# Good step!
# OmegaM:0.0634 ; OmegaL:-0.1043 ; h:0.7953
# Omega_M = 0.063 , Omega_L = -0.104 , H0 = 0.795
# Good step!
# OmegaM:0.0656 ; OmegaL:-0.1024 ; h:0.7802
# Omega_M = 0.066 , Omega_L = -0.102 , H0 = 0.78
# Good step!
# OmegaM:0.0617 ; OmegaL:-0.092 ; h:0.7825
# Omega_M = 0.062 , Omega_L = -0.092 , H0 = 0.783
# Good step!
# OmegaM:0.0738 ; OmegaL:-0.0892 ; h:0.782
# Omega_M = 0.074 , Omega_L = -0.089 , H0 = 0.782
# Good step!
# OmegaM:0.0878 ; OmegaL:-0.0889 ; h:0.7696
# Omega_M = 0.088 , Omega_L = -0.089 , H0 = 0.77
# Good step!
# OmegaM:0.0954 ; OmegaL:-0.081 ; h:0.7475
# Omega_M = 0.095 , Omega_L = -0.081 , H0 = 0.748
# Good step!
# OmegaM:0.1017 ; OmegaL:-0.0754 ; h:0.7588
# Omega_M = 0.102 , Omega_L = -0.075 , H0 = 0.759
# Good step!
# OmegaM:0.1113 ; OmegaL:-0.0828 ; h:0.7579
# Omega_M = 0.111 , Omega_L = -0.083 , H0 = 0.758
# Good step!
# OmegaM:0.0973 ; OmegaL:-0.0951 ; h:0.7631
# Omega_M = 0.097 , Omega_L = -0.095 , H0 = 0.763
# Good step!
# OmegaM:0.0852 ; OmegaL:-0.0893 ; h:0.7554
# Omega_M = 0.085 , Omega_L = -0.089 , H0 = 0.755
# Good step!
# OmegaM:0.0848 ; OmegaL:-0.0834 ; h:0.7463
# Omega_M = 0.085 , Omega_L = -0.083 , H0 = 0.746
# Good step!
# OmegaM:0.0767 ; OmegaL:-0.0859 ; h:0.7325
# Omega_M = 0.077 , Omega_L = -0.086 , H0 = 0.732
# Good step!
# OmegaM:0.1019 ; OmegaL:-0.0831 ; h:0.7298
# Omega_M = 0.102 , Omega_L = -0.083 , H0 = 0.73
# Good step!
# OmegaM:0.0869 ; OmegaL:-0.0869 ; h:0.7331
# Omega_M = 0.087 , Omega_L = -0.087 , H0 = 0.733
# Good step!
# OmegaM:0.0923 ; OmegaL:-0.0848 ; h:0.7335
# Omega_M = 0.092 , Omega_L = -0.085 , H0 = 0.733
# Good step!
# OmegaM:0.0809 ; OmegaL:-0.0802 ; h:0.7484
# Omega_M = 0.081 , Omega_L = -0.08 , H0 = 0.748
# Good step!
# OmegaM:0.0792 ; OmegaL:-0.0677 ; h:0.7512
# Omega_M = 0.079 , Omega_L = -0.068 , H0 = 0.751
# Good step!
# OmegaM:0.0843 ; OmegaL:-0.0928 ; h:0.7607
# Omega_M = 0.084 , Omega_L = -0.093 , H0 = 0.761
# Good step!
# OmegaM:0.0834 ; OmegaL:-0.097 ; h:0.762
# Omega_M = 0.083 , Omega_L = -0.097 , H0 = 0.762
# Good step!
# OmegaM:0.0797 ; OmegaL:-0.0818 ; h:0.7457
# Omega_M = 0.08 , Omega_L = -0.082 , H0 = 0.746
# Good step!
# OmegaM:0.0827 ; OmegaL:-0.0795 ; h:0.7483
# Omega_M = 0.083 , Omega_L = -0.08 , H0 = 0.748
# Good step!
# OmegaM:0.0819 ; OmegaL:-0.0849 ; h:0.7417
# Omega_M = 0.082 , Omega_L = -0.085 , H0 = 0.742
# Good step!
# OmegaM:0.0775 ; OmegaL:-0.0869 ; h:0.7539
# Omega_M = 0.077 , Omega_L = -0.087 , H0 = 0.754
# Good step!
# OmegaM:0.0788 ; OmegaL:-0.0919 ; h:0.7319
# Omega_M = 0.079 , Omega_L = -0.092 , H0 = 0.732
# Good step!
# OmegaM:0.0749 ; OmegaL:-0.0998 ; h:0.7421
# Omega_M = 0.075 , Omega_L = -0.1 , H0 = 0.742
# Good step!
# OmegaM:0.0674 ; OmegaL:-0.1129 ; h:0.74
# Omega_M = 0.067 , Omega_L = -0.113 , H0 = 0.74
# Good step!
# OmegaM:0.0773 ; OmegaL:-0.0993 ; h:0.7373
# Omega_M = 0.077 , Omega_L = -0.099 , H0 = 0.737
# Good step!
# OmegaM:0.102 ; OmegaL:-0.1258 ; h:0.7255
# Omega_M = 0.102 , Omega_L = -0.126 , H0 = 0.725
# Good step!
# OmegaM:0.0965 ; OmegaL:-0.1321 ; h:0.727
# Omega_M = 0.096 , Omega_L = -0.132 , H0 = 0.727
# Good step!
# OmegaM:0.0778 ; OmegaL:-0.1338 ; h:0.7233
# Omega_M = 0.078 , Omega_L = -0.134 , H0 = 0.723
# Good step!
# OmegaM:0.0673 ; OmegaL:-0.1296 ; h:0.7359
# Omega_M = 0.067 , Omega_L = -0.13 , H0 = 0.736
# Good step!
# OmegaM:0.0622 ; OmegaL:-0.1243 ; h:0.7387
# Omega_M = 0.062 , Omega_L = -0.124 , H0 = 0.739
# Good step!
# OmegaM:0.0814 ; OmegaL:-0.1139 ; h:0.7448
# Omega_M = 0.081 , Omega_L = -0.114 , H0 = 0.745
# Good step!
# OmegaM:0.0853 ; OmegaL:-0.1046 ; h:0.741
# Omega_M = 0.085 , Omega_L = -0.105 , H0 = 0.741
# Good step!
# OmegaM:0.0902 ; OmegaL:-0.0981 ; h:0.7475
# Omega_M = 0.09 , Omega_L = -0.098 , H0 = 0.748
# Good step!
# OmegaM:0.1051 ; OmegaL:-0.083 ; h:0.739
# Omega_M = 0.105 , Omega_L = -0.083 , H0 = 0.739
# Good step!
# OmegaM:0.1042 ; OmegaL:-0.0716 ; h:0.7509
# Omega_M = 0.104 , Omega_L = -0.072 , H0 = 0.751
# Good step!
# OmegaM:0.0956 ; OmegaL:-0.0672 ; h:0.7465
# Omega_M = 0.096 , Omega_L = -0.067 , H0 = 0.747
# Good step!
# OmegaM:0.0919 ; OmegaL:-0.0805 ; h:0.735
# Omega_M = 0.092 , Omega_L = -0.081 , H0 = 0.735
# Good step!
# OmegaM:0.1167 ; OmegaL:-0.0634 ; h:0.7296
# Omega_M = 0.117 , Omega_L = -0.063 , H0 = 0.73
# Good step!
# OmegaM:0.1147 ; OmegaL:-0.0477 ; h:0.7167
# Omega_M = 0.115 , Omega_L = -0.048 , H0 = 0.717
# Good step!
# OmegaM:0.1042 ; OmegaL:-0.0437 ; h:0.734
# Omega_M = 0.104 , Omega_L = -0.044 , H0 = 0.734
# Good step!
# OmegaM:0.1016 ; OmegaL:-0.0471 ; h:0.7189
# Omega_M = 0.102 , Omega_L = -0.047 , H0 = 0.719
# Good step!
# OmegaM:0.1013 ; OmegaL:-0.0589 ; h:0.7207
# Omega_M = 0.101 , Omega_L = -0.059 , H0 = 0.721
# Good step!
# OmegaM:0.0925 ; OmegaL:-0.0576 ; h:0.7277
# Omega_M = 0.093 , Omega_L = -0.058 , H0 = 0.728
# Good step!
# OmegaM:0.0884 ; OmegaL:-0.065 ; h:0.7242
# Omega_M = 0.088 , Omega_L = -0.065 , H0 = 0.724
# Good step!
# OmegaM:0.088 ; OmegaL:-0.0769 ; h:0.7282
# Omega_M = 0.088 , Omega_L = -0.077 , H0 = 0.728
# Good step!
# OmegaM:0.0878 ; OmegaL:-0.0877 ; h:0.7287
# Omega_M = 0.088 , Omega_L = -0.088 , H0 = 0.729
# Good step!
# OmegaM:0.0714 ; OmegaL:-0.0974 ; h:0.7422
# Omega_M = 0.071 , Omega_L = -0.097 , H0 = 0.742
# Good step!
# OmegaM:0.0724 ; OmegaL:-0.1026 ; h:0.7473
# Omega_M = 0.072 , Omega_L = -0.103 , H0 = 0.747
# Good step!
# OmegaM:0.067 ; OmegaL:-0.098 ; h:0.7407
# Omega_M = 0.067 , Omega_L = -0.098 , H0 = 0.741
# Good step!
# OmegaM:0.0573 ; OmegaL:-0.0854 ; h:0.7398
# Omega_M = 0.057 , Omega_L = -0.085 , H0 = 0.74
# Good step!
# OmegaM:0.0673 ; OmegaL:-0.0786 ; h:0.7421
# Omega_M = 0.067 , Omega_L = -0.079 , H0 = 0.742
# Good step!
# OmegaM:0.0659 ; OmegaL:-0.073 ; h:0.7297
# Omega_M = 0.066 , Omega_L = -0.073 , H0 = 0.73
# Good step!
# OmegaM:0.0713 ; OmegaL:-0.0685 ; h:0.7147
# Omega_M = 0.071 , Omega_L = -0.069 , H0 = 0.715
# Good step!
# OmegaM:0.0532 ; OmegaL:-0.0887 ; h:0.7038
# Omega_M = 0.053 , Omega_L = -0.089 , H0 = 0.704
# Good step!
# OmegaM:0.0414 ; OmegaL:-0.0967 ; h:0.7046
# Omega_M = 0.041 , Omega_L = -0.097 , H0 = 0.705
# Good step!
# OmegaM:0.0321 ; OmegaL:-0.0972 ; h:0.7152
# Omega_M = 0.032 , Omega_L = -0.097 , H0 = 0.715
# Good step!
# OmegaM:0.0294 ; OmegaL:-0.0818 ; h:0.7014
# Omega_M = 0.029 , Omega_L = -0.082 , H0 = 0.701
# Good step!
# OmegaM:0.0589 ; OmegaL:-0.0843 ; h:0.6938
# Omega_M = 0.059 , Omega_L = -0.084 , H0 = 0.694
# Good step!
# OmegaM:0.074 ; OmegaL:-0.0737 ; h:0.6966
# Omega_M = 0.074 , Omega_L = -0.074 , H0 = 0.697
# Good step!
# OmegaM:0.0883 ; OmegaL:-0.0758 ; h:0.6913
# Omega_M = 0.088 , Omega_L = -0.076 , H0 = 0.691
# Good step!
# OmegaM:0.103 ; OmegaL:-0.0745 ; h:0.7128
# Omega_M = 0.103 , Omega_L = -0.074 , H0 = 0.713
# Good step!
# OmegaM:0.0951 ; OmegaL:-0.0719 ; h:0.7108
# Omega_M = 0.095 , Omega_L = -0.072 , H0 = 0.711
# Good step!
# OmegaM:0.0974 ; OmegaL:-0.071 ; h:0.6988
# Omega_M = 0.097 , Omega_L = -0.071 , H0 = 0.699
# Good step!
# OmegaM:0.0956 ; OmegaL:-0.0468 ; h:0.7019
# Omega_M = 0.096 , Omega_L = -0.047 , H0 = 0.702
# Good step!
# OmegaM:0.0859 ; OmegaL:-0.0295 ; h:0.7133
# Omega_M = 0.086 , Omega_L = -0.03 , H0 = 0.713
# Good step!
# OmegaM:0.0891 ; OmegaL:-0.0057 ; h:0.7379
# Omega_M = 0.089 , Omega_L = -0.006 , H0 = 0.738
# Good step!
# OmegaM:0.0924 ; OmegaL:-0.0185 ; h:0.7413
# Omega_M = 0.092 , Omega_L = -0.019 , H0 = 0.741
# Good step!
# OmegaM:0.0841 ; OmegaL:-0.0195 ; h:0.7312
# Omega_M = 0.084 , Omega_L = -0.019 , H0 = 0.731
# Good step!
# OmegaM:0.1045 ; OmegaL:-0.0161 ; h:0.7124
# Omega_M = 0.105 , Omega_L = -0.016 , H0 = 0.712
# Good step!
# OmegaM:0.1156 ; OmegaL:-0.0193 ; h:0.7256
# Omega_M = 0.116 , Omega_L = -0.019 , H0 = 0.726
# Good step!
# OmegaM:0.1249 ; OmegaL:-0.0164 ; h:0.729
# Omega_M = 0.125 , Omega_L = -0.016 , H0 = 0.729
# Good step!
# OmegaM:0.1335 ; OmegaL:-0.0242 ; h:0.7425
# Omega_M = 0.133 , Omega_L = -0.024 , H0 = 0.743
# Good step!
# OmegaM:0.1181 ; OmegaL:-0.0218 ; h:0.7339
# Omega_M = 0.118 , Omega_L = -0.022 , H0 = 0.734
# Good step!
# OmegaM:0.1253 ; OmegaL:-0.0114 ; h:0.7259
# Omega_M = 0.125 , Omega_L = -0.011 , H0 = 0.726
# Good step!
# OmegaM:0.1303 ; OmegaL:0.0013 ; h:0.7264
# Omega_M = 0.13 , Omega_L = 0.001 , H0 = 0.726
# Good step!
# OmegaM:0.1258 ; OmegaL:-0.0006 ; h:0.721
# Omega_M = 0.126 , Omega_L = -0.001 , H0 = 0.721
# Good step!
# OmegaM:0.1363 ; OmegaL:0.0082 ; h:0.7158
# Omega_M = 0.136 , Omega_L = 0.008 , H0 = 0.716
# Good step!
# OmegaM:0.1241 ; OmegaL:-0.0021 ; h:0.7164
# Omega_M = 0.124 , Omega_L = -0.002 , H0 = 0.716
# Good step!
# OmegaM:0.1274 ; OmegaL:-0.0002 ; h:0.7083
# Omega_M = 0.127 , Omega_L = -0.0 , H0 = 0.708
# Good step!
# OmegaM:0.107 ; OmegaL:-0.0012 ; h:0.725
# Omega_M = 0.107 , Omega_L = -0.001 , H0 = 0.725
# Good step!
# OmegaM:0.096 ; OmegaL:-0.0001 ; h:0.723
# Omega_M = 0.096 , Omega_L = -0.0 , H0 = 0.723
# Good step!
# OmegaM:0.1043 ; OmegaL:0.0041 ; h:0.7112
# Omega_M = 0.104 , Omega_L = 0.004 , H0 = 0.711
# Good step!
# OmegaM:0.1129 ; OmegaL:0.0057 ; h:0.6987
# Omega_M = 0.113 , Omega_L = 0.006 , H0 = 0.699
# Good step!
# OmegaM:0.1154 ; OmegaL:-0.0044 ; h:0.694
# Omega_M = 0.115 , Omega_L = -0.004 , H0 = 0.694
# Good step!
# OmegaM:0.1176 ; OmegaL:-0.0239 ; h:0.6972
# Omega_M = 0.118 , Omega_L = -0.024 , H0 = 0.697
# Good step!
# OmegaM:0.1056 ; OmegaL:-0.0205 ; h:0.6989
# Omega_M = 0.106 , Omega_L = -0.02 , H0 = 0.699
# Good step!
# OmegaM:0.1106 ; OmegaL:-0.0375 ; h:0.7107
# Omega_M = 0.111 , Omega_L = -0.037 , H0 = 0.711
# Good step!
# OmegaM:0.1277 ; OmegaL:-0.0337 ; h:0.7116
# Omega_M = 0.128 , Omega_L = -0.034 , H0 = 0.712
# Good step!
# OmegaM:0.1217 ; OmegaL:-0.0296 ; h:0.7315
# Omega_M = 0.122 , Omega_L = -0.03 , H0 = 0.731
# Good step!
# OmegaM:0.1212 ; OmegaL:-0.0269 ; h:0.7202
# Omega_M = 0.121 , Omega_L = -0.027 , H0 = 0.72
# Good step!
# OmegaM:0.1228 ; OmegaL:-0.0422 ; h:0.7152
# Omega_M = 0.123 , Omega_L = -0.042 , H0 = 0.715
# Good step!
# OmegaM:0.1308 ; OmegaL:-0.037 ; h:0.7145
# Omega_M = 0.131 , Omega_L = -0.037 , H0 = 0.715
# Good step!
# OmegaM:0.1341 ; OmegaL:-0.049 ; h:0.7223
# Omega_M = 0.134 , Omega_L = -0.049 , H0 = 0.722
# Good step!
# OmegaM:0.136 ; OmegaL:-0.0395 ; h:0.7158
# Omega_M = 0.136 , Omega_L = -0.039 , H0 = 0.716
# Good step!
# OmegaM:0.1186 ; OmegaL:-0.0393 ; h:0.7155
# Omega_M = 0.119 , Omega_L = -0.039 , H0 = 0.716
# Good step!
# OmegaM:0.1105 ; OmegaL:-0.0435 ; h:0.7193
# Omega_M = 0.11 , Omega_L = -0.044 , H0 = 0.719
# Good step!
# OmegaM:0.121 ; OmegaL:-0.0485 ; h:0.7183
# Omega_M = 0.121 , Omega_L = -0.048 , H0 = 0.718
# Good step!
# OmegaM:0.1114 ; OmegaL:-0.045 ; h:0.7141
# Omega_M = 0.111 , Omega_L = -0.045 , H0 = 0.714
# Good step!
# OmegaM:0.1065 ; OmegaL:-0.0516 ; h:0.7072
# Omega_M = 0.107 , Omega_L = -0.052 , H0 = 0.707
# Good step!
# OmegaM:0.0967 ; OmegaL:-0.0451 ; h:0.7084
# Omega_M = 0.097 , Omega_L = -0.045 , H0 = 0.708
# Good step!
# OmegaM:0.0978 ; OmegaL:-0.0432 ; h:0.7044
# Omega_M = 0.098 , Omega_L = -0.043 , H0 = 0.704
# Good step!
# OmegaM:0.092 ; OmegaL:-0.0369 ; h:0.7
# Omega_M = 0.092 , Omega_L = -0.037 , H0 = 0.7
# Good step!
# OmegaM:0.089 ; OmegaL:-0.0389 ; h:0.6851
# Omega_M = 0.089 , Omega_L = -0.039 , H0 = 0.685
# Good step!
# OmegaM:0.0921 ; OmegaL:-0.0467 ; h:0.6698
# Omega_M = 0.092 , Omega_L = -0.047 , H0 = 0.67
# Good step!
# OmegaM:0.0919 ; OmegaL:-0.0526 ; h:0.6726
# Omega_M = 0.092 , Omega_L = -0.053 , H0 = 0.673
# Good step!
# OmegaM:0.0891 ; OmegaL:-0.0532 ; h:0.6785
# Omega_M = 0.089 , Omega_L = -0.053 , H0 = 0.678
# Good step!
# OmegaM:0.0881 ; OmegaL:-0.051 ; h:0.6806
# Omega_M = 0.088 , Omega_L = -0.051 , H0 = 0.681
# Good step!
# OmegaM:0.1051 ; OmegaL:-0.0461 ; h:0.6578
# Omega_M = 0.105 , Omega_L = -0.046 , H0 = 0.658
# Good step!
# OmegaM:0.1028 ; OmegaL:-0.0595 ; h:0.6518
# Omega_M = 0.103 , Omega_L = -0.059 , H0 = 0.652
# Good step!
# OmegaM:0.1056 ; OmegaL:-0.0626 ; h:0.6694
# Omega_M = 0.106 , Omega_L = -0.063 , H0 = 0.669
# Good step!
# OmegaM:0.1217 ; OmegaL:-0.0651 ; h:0.673
# Omega_M = 0.122 , Omega_L = -0.065 , H0 = 0.673
# Good step!
# OmegaM:0.1148 ; OmegaL:-0.0783 ; h:0.6505
# Omega_M = 0.115 , Omega_L = -0.078 , H0 = 0.651
# Good step!
# OmegaM:0.1109 ; OmegaL:-0.0526 ; h:0.6367
# Omega_M = 0.111 , Omega_L = -0.053 , H0 = 0.637
# Good step!
# OmegaM:0.1142 ; OmegaL:-0.0387 ; h:0.6326
# Omega_M = 0.114 , Omega_L = -0.039 , H0 = 0.633
# Good step!
# OmegaM:0.1201 ; OmegaL:-0.0315 ; h:0.6269
# Omega_M = 0.12 , Omega_L = -0.031 , H0 = 0.627
# Good step!
# OmegaM:0.0997 ; OmegaL:-0.0337 ; h:0.6222
# Omega_M = 0.1 , Omega_L = -0.034 , H0 = 0.622
# Good step!
# OmegaM:0.106 ; OmegaL:-0.0339 ; h:0.6129
# Omega_M = 0.106 , Omega_L = -0.034 , H0 = 0.613
# Good step!
# OmegaM:0.0911 ; OmegaL:-0.0426 ; h:0.6233
# Omega_M = 0.091 , Omega_L = -0.043 , H0 = 0.623
# Good step!
# OmegaM:0.0948 ; OmegaL:-0.0268 ; h:0.6412
# Omega_M = 0.095 , Omega_L = -0.027 , H0 = 0.641
# Good step!
# OmegaM:0.1084 ; OmegaL:-0.0246 ; h:0.6515
# Omega_M = 0.108 , Omega_L = -0.025 , H0 = 0.651
# Good step!
# OmegaM:0.1175 ; OmegaL:-0.0245 ; h:0.652
# Omega_M = 0.118 , Omega_L = -0.024 , H0 = 0.652
# Good step!
# OmegaM:0.1164 ; OmegaL:-0.0275 ; h:0.6528
# Omega_M = 0.116 , Omega_L = -0.028 , H0 = 0.653
# Good step!
# OmegaM:0.1125 ; OmegaL:-0.019 ; h:0.6556
# Omega_M = 0.113 , Omega_L = -0.019 , H0 = 0.656
# Good step!
# OmegaM:0.132 ; OmegaL:-0.0216 ; h:0.6516
# Omega_M = 0.132 , Omega_L = -0.022 , H0 = 0.652
# Good step!
# OmegaM:0.1382 ; OmegaL:-0.0304 ; h:0.6555
# Omega_M = 0.138 , Omega_L = -0.03 , H0 = 0.655
# Good step!
# OmegaM:0.1375 ; OmegaL:-0.0187 ; h:0.6493
# Omega_M = 0.137 , Omega_L = -0.019 , H0 = 0.649
# Good step!
# OmegaM:0.1554 ; OmegaL:-0.0087 ; h:0.6555
# Omega_M = 0.155 , Omega_L = -0.009 , H0 = 0.656
# Good step!
# OmegaM:0.1433 ; OmegaL:0.0086 ; h:0.6621
# Omega_M = 0.143 , Omega_L = 0.009 , H0 = 0.662
# Good step!
# OmegaM:0.1347 ; OmegaL:0.001 ; h:0.651
# Omega_M = 0.135 , Omega_L = 0.001 , H0 = 0.651
# Good step!
# OmegaM:0.1383 ; OmegaL:0.0242 ; h:0.6559
# Omega_M = 0.138 , Omega_L = 0.024 , H0 = 0.656
# Good step!
# OmegaM:0.1333 ; OmegaL:0.023 ; h:0.6448
# Omega_M = 0.133 , Omega_L = 0.023 , H0 = 0.645
# Good step!
# OmegaM:0.1443 ; OmegaL:0.0075 ; h:0.6484
# Omega_M = 0.144 , Omega_L = 0.008 , H0 = 0.648
# Good step!
# OmegaM:0.1503 ; OmegaL:0.0107 ; h:0.6557
# Omega_M = 0.15 , Omega_L = 0.011 , H0 = 0.656
# Good step!
# OmegaM:0.1507 ; OmegaL:0.0236 ; h:0.6585
# Omega_M = 0.151 , Omega_L = 0.024 , H0 = 0.659
# Good step!
# OmegaM:0.1662 ; OmegaL:0.0128 ; h:0.6684
# Omega_M = 0.166 , Omega_L = 0.013 , H0 = 0.668
# Good step!
# OmegaM:0.1604 ; OmegaL:0.0175 ; h:0.6771
# Omega_M = 0.16 , Omega_L = 0.018 , H0 = 0.677
# Good step!
# OmegaM:0.1667 ; OmegaL:0.0126 ; h:0.6664
# Omega_M = 0.167 , Omega_L = 0.013 , H0 = 0.666
# Good step!
# OmegaM:0.1737 ; OmegaL:0.0004 ; h:0.6886
# Omega_M = 0.174 , Omega_L = 0.0 , H0 = 0.689
# Good step!
# OmegaM:0.1722 ; OmegaL:-0.0049 ; h:0.6932
# Omega_M = 0.172 , Omega_L = -0.005 , H0 = 0.693
# Good step!
# OmegaM:0.1616 ; OmegaL:-0.0143 ; h:0.6871
# Omega_M = 0.162 , Omega_L = -0.014 , H0 = 0.687
# Good step!
# OmegaM:0.1595 ; OmegaL:-0.0178 ; h:0.6925
# Omega_M = 0.16 , Omega_L = -0.018 , H0 = 0.692
# Good step!
# OmegaM:0.1649 ; OmegaL:-0.0423 ; h:0.708
# Omega_M = 0.165 , Omega_L = -0.042 , H0 = 0.708
# Good step!
# OmegaM:0.1763 ; OmegaL:-0.0353 ; h:0.7073
# Omega_M = 0.176 , Omega_L = -0.035 , H0 = 0.707
# Good step!
# OmegaM:0.1636 ; OmegaL:-0.0409 ; h:0.7141
# Omega_M = 0.164 , Omega_L = -0.041 , H0 = 0.714
# Good step!
# OmegaM:0.1603 ; OmegaL:-0.0389 ; h:0.7207
# Omega_M = 0.16 , Omega_L = -0.039 , H0 = 0.721
# Good step!
# OmegaM:0.17 ; OmegaL:-0.0347 ; h:0.7071
# Omega_M = 0.17 , Omega_L = -0.035 , H0 = 0.707
# Good step!
# OmegaM:0.1889 ; OmegaL:-0.0339 ; h:0.7236
# Omega_M = 0.189 , Omega_L = -0.034 , H0 = 0.724
# Good step!
# OmegaM:0.185 ; OmegaL:-0.0254 ; h:0.7406
# Omega_M = 0.185 , Omega_L = -0.025 , H0 = 0.741
# Good step!
# OmegaM:0.1939 ; OmegaL:-0.0382 ; h:0.7519
# Omega_M = 0.194 , Omega_L = -0.038 , H0 = 0.752
# Good step!
# OmegaM:0.1705 ; OmegaL:-0.0453 ; h:0.7521
# Omega_M = 0.17 , Omega_L = -0.045 , H0 = 0.752
# Good step!
# OmegaM:0.1624 ; OmegaL:-0.0348 ; h:0.7601
# Omega_M = 0.162 , Omega_L = -0.035 , H0 = 0.76
# Good step!
# OmegaM:0.1504 ; OmegaL:-0.0289 ; h:0.7631
# Omega_M = 0.15 , Omega_L = -0.029 , H0 = 0.763
# Good step!
# OmegaM:0.1448 ; OmegaL:-0.0235 ; h:0.7415
# Omega_M = 0.145 , Omega_L = -0.023 , H0 = 0.742
# Good step!
# OmegaM:0.1566 ; OmegaL:-0.0177 ; h:0.7334
# Omega_M = 0.157 , Omega_L = -0.018 , H0 = 0.733
# Good step!
# OmegaM:0.147 ; OmegaL:-0.0165 ; h:0.7399
# Omega_M = 0.147 , Omega_L = -0.017 , H0 = 0.74
# Good step!
# OmegaM:0.1478 ; OmegaL:-0.0263 ; h:0.7413
# Omega_M = 0.148 , Omega_L = -0.026 , H0 = 0.741
# Good step!
# OmegaM:0.1305 ; OmegaL:-0.0055 ; h:0.7311
# Omega_M = 0.131 , Omega_L = -0.006 , H0 = 0.731
# Good step!
# OmegaM:0.1123 ; OmegaL:-0.0021 ; h:0.7229
# Omega_M = 0.112 , Omega_L = -0.002 , H0 = 0.723
# Good step!
# OmegaM:0.1235 ; OmegaL:-0.0129 ; h:0.7167
# Omega_M = 0.123 , Omega_L = -0.013 , H0 = 0.717
# Good step!
# OmegaM:0.106 ; OmegaL:-0.022 ; h:0.7122
# Omega_M = 0.106 , Omega_L = -0.022 , H0 = 0.712
# Good step!
# OmegaM:0.0879 ; OmegaL:-0.0253 ; h:0.7168
# Omega_M = 0.088 , Omega_L = -0.025 , H0 = 0.717
# Good step!
# OmegaM:0.0897 ; OmegaL:-0.0296 ; h:0.6993
# Omega_M = 0.09 , Omega_L = -0.03 , H0 = 0.699
# Good step!
# OmegaM:0.0911 ; OmegaL:-0.0303 ; h:0.7043
# Omega_M = 0.091 , Omega_L = -0.03 , H0 = 0.704
# Good step!
# OmegaM:0.0825 ; OmegaL:-0.0308 ; h:0.6897
# Omega_M = 0.083 , Omega_L = -0.031 , H0 = 0.69
# Good step!
# OmegaM:0.0808 ; OmegaL:-0.0264 ; h:0.6957
# Omega_M = 0.081 , Omega_L = -0.026 , H0 = 0.696
# Good step!
# OmegaM:0.083 ; OmegaL:-0.0311 ; h:0.7232
# Omega_M = 0.083 , Omega_L = -0.031 , H0 = 0.723
# Good step!
# OmegaM:0.1026 ; OmegaL:-0.043 ; h:0.7136
# Omega_M = 0.103 , Omega_L = -0.043 , H0 = 0.714
# Good step!
# OmegaM:0.1103 ; OmegaL:-0.0439 ; h:0.7355
# Omega_M = 0.11 , Omega_L = -0.044 , H0 = 0.736
# Good step!
# OmegaM:0.0979 ; OmegaL:-0.0466 ; h:0.7438
# Omega_M = 0.098 , Omega_L = -0.047 , H0 = 0.744
# Good step!
# OmegaM:0.0932 ; OmegaL:-0.0578 ; h:0.7576
# Omega_M = 0.093 , Omega_L = -0.058 , H0 = 0.758
# Good step!
# OmegaM:0.0777 ; OmegaL:-0.0606 ; h:0.7548
# Omega_M = 0.078 , Omega_L = -0.061 , H0 = 0.755
# Good step!
# OmegaM:0.0787 ; OmegaL:-0.0613 ; h:0.7523
# Omega_M = 0.079 , Omega_L = -0.061 , H0 = 0.752
# Good step!
# OmegaM:0.0758 ; OmegaL:-0.0596 ; h:0.7548
# Omega_M = 0.076 , Omega_L = -0.06 , H0 = 0.755
# Good step!
# OmegaM:0.0648 ; OmegaL:-0.0638 ; h:0.7532
# Omega_M = 0.065 , Omega_L = -0.064 , H0 = 0.753
# Good step!
# OmegaM:0.0686 ; OmegaL:-0.059 ; h:0.7522
# Omega_M = 0.069 , Omega_L = -0.059 , H0 = 0.752
# Good step!
# OmegaM:0.0684 ; OmegaL:-0.057 ; h:0.7598
# Omega_M = 0.068 , Omega_L = -0.057 , H0 = 0.76
# Good step!
# OmegaM:0.0758 ; OmegaL:-0.0547 ; h:0.7445
# Omega_M = 0.076 , Omega_L = -0.055 , H0 = 0.745
# Good step!
# OmegaM:0.089 ; OmegaL:-0.0497 ; h:0.7596
# Omega_M = 0.089 , Omega_L = -0.05 , H0 = 0.76
# Good step!
# OmegaM:0.0817 ; OmegaL:-0.0513 ; h:0.7672
# Omega_M = 0.082 , Omega_L = -0.051 , H0 = 0.767
# Good step!
# OmegaM:0.0915 ; OmegaL:-0.0458 ; h:0.7752
# Omega_M = 0.091 , Omega_L = -0.046 , H0 = 0.775
# Good step!
# OmegaM:0.1019 ; OmegaL:-0.0486 ; h:0.775
# Omega_M = 0.102 , Omega_L = -0.049 , H0 = 0.775
# Good step!
# OmegaM:0.1118 ; OmegaL:-0.0565 ; h:0.7752
# Omega_M = 0.112 , Omega_L = -0.056 , H0 = 0.775
# Good step!
# OmegaM:0.1148 ; OmegaL:-0.0521 ; h:0.7917
# Omega_M = 0.115 , Omega_L = -0.052 , H0 = 0.792
# Good step!
# OmegaM:0.1251 ; OmegaL:-0.0526 ; h:0.7841
# Omega_M = 0.125 , Omega_L = -0.053 , H0 = 0.784
# Good step!
# OmegaM:0.1357 ; OmegaL:-0.0503 ; h:0.7796
# Omega_M = 0.136 , Omega_L = -0.05 , H0 = 0.78
# Good step!
# OmegaM:0.125 ; OmegaL:-0.0632 ; h:0.7676
# Omega_M = 0.125 , Omega_L = -0.063 , H0 = 0.768
# Good step!
# OmegaM:0.1138 ; OmegaL:-0.062 ; h:0.7759
# Omega_M = 0.114 , Omega_L = -0.062 , H0 = 0.776
# Good step!
# OmegaM:0.0999 ; OmegaL:-0.0658 ; h:0.7948
# Omega_M = 0.1 , Omega_L = -0.066 , H0 = 0.795
# Good step!
# OmegaM:0.1034 ; OmegaL:-0.0661 ; h:0.8004
# Omega_M = 0.103 , Omega_L = -0.066 , H0 = 0.8
# Good step!
# OmegaM:0.0987 ; OmegaL:-0.07 ; h:0.811
# Omega_M = 0.099 , Omega_L = -0.07 , H0 = 0.811
# Good step!
# OmegaM:0.1093 ; OmegaL:-0.064 ; h:0.8124
# Omega_M = 0.109 , Omega_L = -0.064 , H0 = 0.812
# Good step!
# OmegaM:0.1003 ; OmegaL:-0.0549 ; h:0.8123
# Omega_M = 0.1 , Omega_L = -0.055 , H0 = 0.812
# Good step!
# OmegaM:0.0877 ; OmegaL:-0.0521 ; h:0.8341
# Omega_M = 0.088 , Omega_L = -0.052 , H0 = 0.834
# Good step!
# OmegaM:0.0993 ; OmegaL:-0.0471 ; h:0.8312
# Omega_M = 0.099 , Omega_L = -0.047 , H0 = 0.831
# Good step!
# OmegaM:0.1019 ; OmegaL:-0.0571 ; h:0.8321
# Omega_M = 0.102 , Omega_L = -0.057 , H0 = 0.832
# Good step!
# OmegaM:0.0898 ; OmegaL:-0.0786 ; h:0.8389
# Omega_M = 0.09 , Omega_L = -0.079 , H0 = 0.839
# Good step!
# OmegaM:0.08 ; OmegaL:-0.0777 ; h:0.8352
# Omega_M = 0.08 , Omega_L = -0.078 , H0 = 0.835
# Good step!
# OmegaM:0.0754 ; OmegaL:-0.0722 ; h:0.8276
# Omega_M = 0.075 , Omega_L = -0.072 , H0 = 0.828
# Good step!
# OmegaM:0.0682 ; OmegaL:-0.0727 ; h:0.8231
# Omega_M = 0.068 , Omega_L = -0.073 , H0 = 0.823
# Good step!
# OmegaM:0.067 ; OmegaL:-0.072 ; h:0.8219
# Omega_M = 0.067 , Omega_L = -0.072 , H0 = 0.822
# Good step!
# OmegaM:0.0582 ; OmegaL:-0.0727 ; h:0.8112
# Omega_M = 0.058 , Omega_L = -0.073 , H0 = 0.811
# Good step!
# OmegaM:0.0659 ; OmegaL:-0.0696 ; h:0.815
# Omega_M = 0.066 , Omega_L = -0.07 , H0 = 0.815
# Good step!
# OmegaM:0.0671 ; OmegaL:-0.0667 ; h:0.8199
# Omega_M = 0.067 , Omega_L = -0.067 , H0 = 0.82
# Good step!
# OmegaM:0.0773 ; OmegaL:-0.0842 ; h:0.8238
# Omega_M = 0.077 , Omega_L = -0.084 , H0 = 0.824
# Good step!
# OmegaM:0.0639 ; OmegaL:-0.0897 ; h:0.8214
# Omega_M = 0.064 , Omega_L = -0.09 , H0 = 0.821
# Good step!
# OmegaM:0.0592 ; OmegaL:-0.0906 ; h:0.8265
# Omega_M = 0.059 , Omega_L = -0.091 , H0 = 0.826
# Good step!
# OmegaM:0.0733 ; OmegaL:-0.0937 ; h:0.8247
# Omega_M = 0.073 , Omega_L = -0.094 , H0 = 0.825
# Good step!
# OmegaM:0.0629 ; OmegaL:-0.0917 ; h:0.8458
# Omega_M = 0.063 , Omega_L = -0.092 , H0 = 0.846
# Good step!
# OmegaM:0.0755 ; OmegaL:-0.0918 ; h:0.831
# Omega_M = 0.076 , Omega_L = -0.092 , H0 = 0.831
# Good step!
# OmegaM:0.0725 ; OmegaL:-0.1031 ; h:0.8267
# Omega_M = 0.072 , Omega_L = -0.103 , H0 = 0.827
# Good step!
# OmegaM:0.0821 ; OmegaL:-0.083 ; h:0.8076
# Omega_M = 0.082 , Omega_L = -0.083 , H0 = 0.808
# Good step!
# OmegaM:0.0941 ; OmegaL:-0.1023 ; h:0.8135
# Omega_M = 0.094 , Omega_L = -0.102 , H0 = 0.814
# Good step!
# OmegaM:0.0945 ; OmegaL:-0.1125 ; h:0.8247
# Omega_M = 0.095 , Omega_L = -0.112 , H0 = 0.825
# Good step!
# OmegaM:0.0842 ; OmegaL:-0.1052 ; h:0.829
# Omega_M = 0.084 , Omega_L = -0.105 , H0 = 0.829
# Good step!
# OmegaM:0.1115 ; OmegaL:-0.0853 ; h:0.8259
# Omega_M = 0.111 , Omega_L = -0.085 , H0 = 0.826
# Good step!
# OmegaM:0.0944 ; OmegaL:-0.0997 ; h:0.8259
# Omega_M = 0.094 , Omega_L = -0.1 , H0 = 0.826
# Good step!
# OmegaM:0.0923 ; OmegaL:-0.107 ; h:0.8256
# Omega_M = 0.092 , Omega_L = -0.107 , H0 = 0.826
# Good step!
# OmegaM:0.0809 ; OmegaL:-0.1013 ; h:0.8229
# Omega_M = 0.081 , Omega_L = -0.101 , H0 = 0.823
# Good step!
# OmegaM:0.0889 ; OmegaL:-0.0878 ; h:0.8246
# Omega_M = 0.089 , Omega_L = -0.088 , H0 = 0.825
# Good step!
# OmegaM:0.0785 ; OmegaL:-0.0877 ; h:0.8186
# Omega_M = 0.079 , Omega_L = -0.088 , H0 = 0.819
# Good step!
# OmegaM:0.0673 ; OmegaL:-0.0772 ; h:0.8101
# Omega_M = 0.067 , Omega_L = -0.077 , H0 = 0.81
# Good step!
# OmegaM:0.0673 ; OmegaL:-0.0773 ; h:0.8246
# Omega_M = 0.067 , Omega_L = -0.077 , H0 = 0.825
# Good step!
# OmegaM:0.0552 ; OmegaL:-0.0738 ; h:0.8158
# Omega_M = 0.055 , Omega_L = -0.074 , H0 = 0.816
# Good step!
# OmegaM:0.0517 ; OmegaL:-0.061 ; h:0.8182
# Omega_M = 0.052 , Omega_L = -0.061 , H0 = 0.818
# Good step!
# OmegaM:0.0603 ; OmegaL:-0.0601 ; h:0.8346
# Omega_M = 0.06 , Omega_L = -0.06 , H0 = 0.835
# Good step!
# OmegaM:0.0582 ; OmegaL:-0.0699 ; h:0.8411
# Omega_M = 0.058 , Omega_L = -0.07 , H0 = 0.841
# Good step!
# OmegaM:0.0558 ; OmegaL:-0.0494 ; h:0.8364
# Omega_M = 0.056 , Omega_L = -0.049 , H0 = 0.836
# Good step!
# OmegaM:0.0458 ; OmegaL:-0.0571 ; h:0.861
# Omega_M = 0.046 , Omega_L = -0.057 , H0 = 0.861
# Good step!
# OmegaM:0.0362 ; OmegaL:-0.0579 ; h:0.8798
# Omega_M = 0.036 , Omega_L = -0.058 , H0 = 0.88
# Good step!
# OmegaM:0.0302 ; OmegaL:-0.0496 ; h:0.8631
# Omega_M = 0.03 , Omega_L = -0.05 , H0 = 0.863
# Good step!
# OmegaM:0.0396 ; OmegaL:-0.034 ; h:0.8622
# Omega_M = 0.04 , Omega_L = -0.034 , H0 = 0.862
# Good step!
# OmegaM:0.0426 ; OmegaL:-0.0413 ; h:0.8525
# Omega_M = 0.043 , Omega_L = -0.041 , H0 = 0.852
# Good step!
# OmegaM:0.0541 ; OmegaL:-0.0519 ; h:0.8423
# Omega_M = 0.054 , Omega_L = -0.052 , H0 = 0.842
# Good step!
# OmegaM:0.0649 ; OmegaL:-0.0398 ; h:0.8377
# Omega_M = 0.065 , Omega_L = -0.04 , H0 = 0.838
# Good step!
# OmegaM:0.0728 ; OmegaL:-0.0274 ; h:0.8354
# Omega_M = 0.073 , Omega_L = -0.027 , H0 = 0.835
# Good step!
# OmegaM:0.0585 ; OmegaL:-0.019 ; h:0.8615
# Omega_M = 0.059 , Omega_L = -0.019 , H0 = 0.862
# Good step!
# OmegaM:0.0489 ; OmegaL:-0.0164 ; h:0.8538
# Omega_M = 0.049 , Omega_L = -0.016 , H0 = 0.854
# Good step!
# OmegaM:0.0492 ; OmegaL:-0.0018 ; h:0.8369
# Omega_M = 0.049 , Omega_L = -0.002 , H0 = 0.837
# Good step!
# OmegaM:0.048 ; OmegaL:0.0022 ; h:0.8272
# Omega_M = 0.048 , Omega_L = 0.002 , H0 = 0.827
# Good step!
# OmegaM:0.0377 ; OmegaL:-0.0018 ; h:0.8258
# Omega_M = 0.038 , Omega_L = -0.002 , H0 = 0.826
# Good step!
# OmegaM:0.0336 ; OmegaL:-0.0059 ; h:0.8147
# Omega_M = 0.034 , Omega_L = -0.006 , H0 = 0.815
# Good step!
# OmegaM:0.0226 ; OmegaL:-0.0004 ; h:0.8352
# Omega_M = 0.023 , Omega_L = -0.0 , H0 = 0.835
# Good step!
# OmegaM:0.0342 ; OmegaL:-0.009 ; h:0.8412
# Omega_M = 0.034 , Omega_L = -0.009 , H0 = 0.841
# Good step!
# OmegaM:0.0453 ; OmegaL:-0.0041 ; h:0.8512
# Omega_M = 0.045 , Omega_L = -0.004 , H0 = 0.851
# Good step!
# OmegaM:0.0456 ; OmegaL:-0.0042 ; h:0.8458
# Omega_M = 0.046 , Omega_L = -0.004 , H0 = 0.846
# Good step!
# OmegaM:0.0453 ; OmegaL:0.0042 ; h:0.842
# Omega_M = 0.045 , Omega_L = 0.004 , H0 = 0.842
# Good step!
# OmegaM:0.039 ; OmegaL:-0.0067 ; h:0.8343
# Omega_M = 0.039 , Omega_L = -0.007 , H0 = 0.834
# Good step!
# OmegaM:0.0231 ; OmegaL:0.006 ; h:0.8197
# Omega_M = 0.023 , Omega_L = 0.006 , H0 = 0.82
# Good step!
# OmegaM:0.0316 ; OmegaL:0.0156 ; h:0.8496
# ...
# Good step!
# OmegaM:-0.0289 ; OmegaL:-0.092 ; h:0.7026
# Omega_M = -0.029 , Omega_L = -0.092 , H0 = 0.703
# Good step!
# OmegaM:-0.0264 ; OmegaL:-0.1023 ; h:0.7101
# Omega_M = -0.026 , Omega_L = -0.102 , H0 = 0.71
# Good step!
# OmegaM:-0.0262 ; OmegaL:-0.1026 ; h:0.7155
# Omega_M = -0.026 , Omega_L = -0.103 , H0 = 0.715
# Good step!
# OmegaM:-0.0216 ; OmegaL:-0.0955 ; h:0.7243
# Omega_M = -0.022 , Omega_L = -0.096 , H0 = 0.724
# Good step!
# OmegaM:-0.0148 ; OmegaL:-0.1041 ; h:0.717
# Omega_M = -0.015 , Omega_L = -0.104 , H0 = 0.717
# Good step!
# OmegaM:-0.0036 ; OmegaL:-0.1086 ; h:0.7346
# Omega_M = -0.004 , Omega_L = -0.109 , H0 = 0.735
# Good step!
# OmegaM:-0.0038 ; OmegaL:-0.1187 ; h:0.7427
# Omega_M = -0.004 , Omega_L = -0.119 , H0 = 0.743
# Good step!
# OmegaM:-0.0112 ; OmegaL:-0.1124 ; h:0.7434
# Omega_M = -0.011 , Omega_L = -0.112 , H0 = 0.743
# Good step!
# OmegaM:-0.004 ; OmegaL:-0.1222 ; h:0.7469
# Omega_M = -0.004 , Omega_L = -0.122 , H0 = 0.747
# Good step!
# OmegaM:-0.0052 ; OmegaL:-0.1155 ; h:0.7332
# Omega_M = -0.005 , Omega_L = -0.115 , H0 = 0.733
# Good step!
# OmegaM:-0.0208 ; OmegaL:-0.0996 ; h:0.7449
# Omega_M = -0.021 , Omega_L = -0.1 , H0 = 0.745
# Good step!
# OmegaM:-0.0286 ; OmegaL:-0.1164 ; h:0.745
# Omega_M = -0.029 , Omega_L = -0.116 , H0 = 0.745
# Good step!
# OmegaM:-0.0227 ; OmegaL:-0.1235 ; h:0.7496
# Omega_M = -0.023 , Omega_L = -0.123 , H0 = 0.75
# Good step!
# OmegaM:-0.0373 ; OmegaL:-0.1223 ; h:0.7426
# Omega_M = -0.037 , Omega_L = -0.122 , H0 = 0.743
# Good step!
# OmegaM:-0.0377 ; OmegaL:-0.1314 ; h:0.7566
# Omega_M = -0.038 , Omega_L = -0.131 , H0 = 0.757
# Good step!
# OmegaM:-0.0477 ; OmegaL:-0.1195 ; h:0.7583
# Omega_M = -0.048 , Omega_L = -0.12 , H0 = 0.758
# Good step!
# OmegaM:-0.0412 ; OmegaL:-0.1227 ; h:0.7576
# Omega_M = -0.041 , Omega_L = -0.123 , H0 = 0.758
# Good step!
# OmegaM:-0.041 ; OmegaL:-0.1305 ; h:0.7698
# Omega_M = -0.041 , Omega_L = -0.131 , H0 = 0.77
# Good step!
# OmegaM:-0.0381 ; OmegaL:-0.1318 ; h:0.7702
# Omega_M = -0.038 , Omega_L = -0.132 , H0 = 0.77
# Good step!
# OmegaM:-0.041 ; OmegaL:-0.128 ; h:0.7558
# Omega_M = -0.041 , Omega_L = -0.128 , H0 = 0.756
# Good step!
# OmegaM:-0.043 ; OmegaL:-0.1225 ; h:0.7526
# Omega_M = -0.043 , Omega_L = -0.123 , H0 = 0.753
# Good step!
# OmegaM:-0.02 ; OmegaL:-0.1382 ; h:0.7497
# Omega_M = -0.02 , Omega_L = -0.138 , H0 = 0.75
# Good step!
# OmegaM:-0.0012 ; OmegaL:-0.1187 ; h:0.7438
# Omega_M = -0.001 , Omega_L = -0.119 , H0 = 0.744
# Good step!
# OmegaM:-0.003 ; OmegaL:-0.1091 ; h:0.7432
# Omega_M = -0.003 , Omega_L = -0.109 , H0 = 0.743
# Good step!
# OmegaM:-0.0215 ; OmegaL:-0.1228 ; h:0.7527
# Omega_M = -0.022 , Omega_L = -0.123 , H0 = 0.753
# Good step!
# OmegaM:-0.0228 ; OmegaL:-0.1174 ; h:0.7493
# Omega_M = -0.023 , Omega_L = -0.117 , H0 = 0.749
# Good step!
# OmegaM:-0.0144 ; OmegaL:-0.1278 ; h:0.7441
# Omega_M = -0.014 , Omega_L = -0.128 , H0 = 0.744
# Good step!
# OmegaM:-0.0132 ; OmegaL:-0.1323 ; h:0.7357
# Omega_M = -0.013 , Omega_L = -0.132 , H0 = 0.736
# Good step!
# OmegaM:-0.0084 ; OmegaL:-0.128 ; h:0.7312
# Omega_M = -0.008 , Omega_L = -0.128 , H0 = 0.731
# Good step!
# OmegaM:0.008 ; OmegaL:-0.1171 ; h:0.71
# Omega_M = 0.008 , Omega_L = -0.117 , H0 = 0.71
# Good step!
# OmegaM:0.0123 ; OmegaL:-0.1097 ; h:0.6885
# Omega_M = 0.012 , Omega_L = -0.11 , H0 = 0.688
# Good step!
# OmegaM:0.0219 ; OmegaL:-0.1198 ; h:0.6759
# Omega_M = 0.022 , Omega_L = -0.12 , H0 = 0.676
# Good step!
# OmegaM:0.0109 ; OmegaL:-0.1191 ; h:0.6625
# Omega_M = 0.011 , Omega_L = -0.119 , H0 = 0.662
# Good step!
# OmegaM:0.0144 ; OmegaL:-0.1064 ; h:0.6497
# Omega_M = 0.014 , Omega_L = -0.106 , H0 = 0.65
# Good step!
# OmegaM:0.0249 ; OmegaL:-0.1019 ; h:0.6533
# Omega_M = 0.025 , Omega_L = -0.102 , H0 = 0.653
# Good step!
# OmegaM:0.03 ; OmegaL:-0.0931 ; h:0.6655
# Omega_M = 0.03 , Omega_L = -0.093 , H0 = 0.666
# Good step!
# OmegaM:0.0181 ; OmegaL:-0.0973 ; h:0.6333
# Omega_M = 0.018 , Omega_L = -0.097 , H0 = 0.633
# Good step!
# OmegaM:0.0067 ; OmegaL:-0.0907 ; h:0.6356
# Omega_M = 0.007 , Omega_L = -0.091 , H0 = 0.636
# Good step!
# OmegaM:0.0007 ; OmegaL:-0.0786 ; h:0.638
# Omega_M = 0.001 , Omega_L = -0.079 , H0 = 0.638
# Good step!
# OmegaM:-0.0217 ; OmegaL:-0.0747 ; h:0.646
# Omega_M = -0.022 , Omega_L = -0.075 , H0 = 0.646
# Good step!
# OmegaM:0.0101 ; OmegaL:-0.0664 ; h:0.6269
# Omega_M = 0.01 , Omega_L = -0.066 , H0 = 0.627
# Good step!
# OmegaM:-0.0055 ; OmegaL:-0.067 ; h:0.6191
# Omega_M = -0.006 , Omega_L = -0.067 , H0 = 0.619
# Good step!
# OmegaM:-0.006 ; OmegaL:-0.0771 ; h:0.6157
# Omega_M = -0.006 , Omega_L = -0.077 , H0 = 0.616
# Good step!
# OmegaM:0.006 ; OmegaL:-0.0765 ; h:0.6145
# Omega_M = 0.006 , Omega_L = -0.076 , H0 = 0.615
# Good step!
# OmegaM:-0.0114 ; OmegaL:-0.0905 ; h:0.6189
# Omega_M = -0.011 , Omega_L = -0.09 , H0 = 0.619
# Good step!
# OmegaM:-0.0052 ; OmegaL:-0.1 ; h:0.6241
# Omega_M = -0.005 , Omega_L = -0.1 , H0 = 0.624
# Good step!
# OmegaM:0.0034 ; OmegaL:-0.0989 ; h:0.6312
# Omega_M = 0.003 , Omega_L = -0.099 , H0 = 0.631
# Good step!
# OmegaM:-0.003 ; OmegaL:-0.119 ; h:0.6066
# Omega_M = -0.003 , Omega_L = -0.119 , H0 = 0.607
# Good step!
# OmegaM:-0.0042 ; OmegaL:-0.1226 ; h:0.6003
# Omega_M = -0.004 , Omega_L = -0.123 , H0 = 0.6
# Good step!
# OmegaM:-0.0019 ; OmegaL:-0.1182 ; h:0.6212
# Omega_M = -0.002 , Omega_L = -0.118 , H0 = 0.621
# Good step!
# OmegaM:0.001 ; OmegaL:-0.1357 ; h:0.6078
# Omega_M = 0.001 , Omega_L = -0.136 , H0 = 0.608
# Good step!
# OmegaM:0.0067 ; OmegaL:-0.1294 ; h:0.6018
# Omega_M = 0.007 , Omega_L = -0.129 , H0 = 0.602
# Good step!
# OmegaM:0.0019 ; OmegaL:-0.1256 ; h:0.5949
# Omega_M = 0.002 , Omega_L = -0.126 , H0 = 0.595
# Good step!
# OmegaM:0.0175 ; OmegaL:-0.1197 ; h:0.5912
# Omega_M = 0.018 , Omega_L = -0.12 , H0 = 0.591
# Good step!
# OmegaM:0.0168 ; OmegaL:-0.1174 ; h:0.6008
# Omega_M = 0.017 , Omega_L = -0.117 , H0 = 0.601
# Good step!
# OmegaM:0.0212 ; OmegaL:-0.0966 ; h:0.5944
# Omega_M = 0.021 , Omega_L = -0.097 , H0 = 0.594
# Good step!
# OmegaM:0.029 ; OmegaL:-0.102 ; h:0.6034
# Omega_M = 0.029 , Omega_L = -0.102 , H0 = 0.603
# Good step!
# OmegaM:0.0418 ; OmegaL:-0.1073 ; h:0.5946
# Omega_M = 0.042 , Omega_L = -0.107 , H0 = 0.595
# Good step!
# OmegaM:0.0572 ; OmegaL:-0.1015 ; h:0.5908
# Omega_M = 0.057 , Omega_L = -0.101 , H0 = 0.591
# Good step!
# OmegaM:0.0691 ; OmegaL:-0.0984 ; h:0.581
# Omega_M = 0.069 , Omega_L = -0.098 , H0 = 0.581
# Good step!
# OmegaM:0.0582 ; OmegaL:-0.0925 ; h:0.5769
# Omega_M = 0.058 , Omega_L = -0.093 , H0 = 0.577
# Good step!
# OmegaM:0.0495 ; OmegaL:-0.0866 ; h:0.5801
# Omega_M = 0.05 , Omega_L = -0.087 , H0 = 0.58
# Good step!
# OmegaM:0.0491 ; OmegaL:-0.0867 ; h:0.5888
# Omega_M = 0.049 , Omega_L = -0.087 , H0 = 0.589
# Good step!
# OmegaM:0.0299 ; OmegaL:-0.096 ; h:0.5703
# Omega_M = 0.03 , Omega_L = -0.096 , H0 = 0.57
# Good step!
# OmegaM:0.0445 ; OmegaL:-0.1001 ; h:0.5639
# Omega_M = 0.044 , Omega_L = -0.1 , H0 = 0.564
# Good step!
# OmegaM:0.0515 ; OmegaL:-0.1104 ; h:0.568
# Omega_M = 0.051 , Omega_L = -0.11 , H0 = 0.568
# Good step!
# OmegaM:0.0571 ; OmegaL:-0.1007 ; h:0.5748
# Omega_M = 0.057 , Omega_L = -0.101 , H0 = 0.575
# Good step!
# OmegaM:0.0771 ; OmegaL:-0.0921 ; h:0.5717
# Omega_M = 0.077 , Omega_L = -0.092 , H0 = 0.572
# Good step!
# OmegaM:0.0721 ; OmegaL:-0.1069 ; h:0.5776
# Omega_M = 0.072 , Omega_L = -0.107 , H0 = 0.578
# Good step!
# OmegaM:0.0707 ; OmegaL:-0.1253 ; h:0.5772
# Omega_M = 0.071 , Omega_L = -0.125 , H0 = 0.577
# Good step!
# OmegaM:0.0863 ; OmegaL:-0.1296 ; h:0.567
# Omega_M = 0.086 , Omega_L = -0.13 , H0 = 0.567
# Good step!
# OmegaM:0.0718 ; OmegaL:-0.1259 ; h:0.5707
# Omega_M = 0.072 , Omega_L = -0.126 , H0 = 0.571
# Good step!
# OmegaM:0.0782 ; OmegaL:-0.1404 ; h:0.5602
# Omega_M = 0.078 , Omega_L = -0.14 , H0 = 0.56
# Good step!
# OmegaM:0.0846 ; OmegaL:-0.1465 ; h:0.5716
# Omega_M = 0.085 , Omega_L = -0.146 , H0 = 0.572
# Good step!
# OmegaM:0.0698 ; OmegaL:-0.1518 ; h:0.5708
# Omega_M = 0.07 , Omega_L = -0.152 , H0 = 0.571
# Good step!
# OmegaM:0.0606 ; OmegaL:-0.1476 ; h:0.5606
# Omega_M = 0.061 , Omega_L = -0.148 , H0 = 0.561
# Good step!
# OmegaM:0.0491 ; OmegaL:-0.1412 ; h:0.5767
# Omega_M = 0.049 , Omega_L = -0.141 , H0 = 0.577
# Good step!
# OmegaM:0.0576 ; OmegaL:-0.152 ; h:0.5748
# Omega_M = 0.058 , Omega_L = -0.152 , H0 = 0.575
# Good step!
# OmegaM:0.072 ; OmegaL:-0.1492 ; h:0.5693
# Omega_M = 0.072 , Omega_L = -0.149 , H0 = 0.569
# Good step!
# OmegaM:0.0725 ; OmegaL:-0.1522 ; h:0.575
# Omega_M = 0.073 , Omega_L = -0.152 , H0 = 0.575
# Good step!
# OmegaM:0.0621 ; OmegaL:-0.1526 ; h:0.5773
# Omega_M = 0.062 , Omega_L = -0.153 , H0 = 0.577
# Good step!
# OmegaM:0.0541 ; OmegaL:-0.1649 ; h:0.5768
# Omega_M = 0.054 , Omega_L = -0.165 , H0 = 0.577
# Good step!
# OmegaM:0.053 ; OmegaL:-0.1745 ; h:0.5632
# Omega_M = 0.053 , Omega_L = -0.175 , H0 = 0.563
# Good step!
# OmegaM:0.0547 ; OmegaL:-0.1675 ; h:0.5545
# Omega_M = 0.055 , Omega_L = -0.167 , H0 = 0.554
# Good step!
# OmegaM:0.062 ; OmegaL:-0.169 ; h:0.5585
# Omega_M = 0.062 , Omega_L = -0.169 , H0 = 0.558
# Good step!
# OmegaM:0.0759 ; OmegaL:-0.1651 ; h:0.5658
# Omega_M = 0.076 , Omega_L = -0.165 , H0 = 0.566
# Good step!
# OmegaM:0.0805 ; OmegaL:-0.1531 ; h:0.5608
# Omega_M = 0.08 , Omega_L = -0.153 , H0 = 0.561
# Good step!
# OmegaM:0.0888 ; OmegaL:-0.1728 ; h:0.5676
# Omega_M = 0.089 , Omega_L = -0.173 , H0 = 0.568
# Good step!
# OmegaM:0.08 ; OmegaL:-0.1867 ; h:0.5686
# Omega_M = 0.08 , Omega_L = -0.187 , H0 = 0.569
# Good step!
# OmegaM:0.0684 ; OmegaL:-0.1729 ; h:0.5643
# Omega_M = 0.068 , Omega_L = -0.173 , H0 = 0.564
# Good step!
# OmegaM:0.0585 ; OmegaL:-0.1663 ; h:0.5729
# Omega_M = 0.058 , Omega_L = -0.166 , H0 = 0.573
# Good step!
# OmegaM:0.052 ; OmegaL:-0.1735 ; h:0.582
# Omega_M = 0.052 , Omega_L = -0.173 , H0 = 0.582
# Good step!
# OmegaM:0.0674 ; OmegaL:-0.1653 ; h:0.5611
# Omega_M = 0.067 , Omega_L = -0.165 , H0 = 0.561
# Good step!
# OmegaM:0.0741 ; OmegaL:-0.1679 ; h:0.5783
# Omega_M = 0.074 , Omega_L = -0.168 , H0 = 0.578
# Good step!
# OmegaM:0.0825 ; OmegaL:-0.1762 ; h:0.5769
# Omega_M = 0.083 , Omega_L = -0.176 , H0 = 0.577
# Good step!
# OmegaM:0.0874 ; OmegaL:-0.1886 ; h:0.5851
# Omega_M = 0.087 , Omega_L = -0.189 , H0 = 0.585
# Good step!
# OmegaM:0.0975 ; OmegaL:-0.2002 ; h:0.5934
# Omega_M = 0.097 , Omega_L = -0.2 , H0 = 0.593
# Good step!
# OmegaM:0.0947 ; OmegaL:-0.1911 ; h:0.5953
# Omega_M = 0.095 , Omega_L = -0.191 , H0 = 0.595
# Good step!
# OmegaM:0.0905 ; OmegaL:-0.1906 ; h:0.5848
# Omega_M = 0.091 , Omega_L = -0.191 , H0 = 0.585
# Good step!
# OmegaM:0.0817 ; OmegaL:-0.1907 ; h:0.6106
# Omega_M = 0.082 , Omega_L = -0.191 , H0 = 0.611
# Good step!
# OmegaM:0.0842 ; OmegaL:-0.2015 ; h:0.6098
# Omega_M = 0.084 , Omega_L = -0.201 , H0 = 0.61
# Good step!
# OmegaM:0.0735 ; OmegaL:-0.1855 ; h:0.629
# Omega_M = 0.073 , Omega_L = -0.186 , H0 = 0.629
# Good step!
# OmegaM:0.0767 ; OmegaL:-0.1806 ; h:0.6257
# Omega_M = 0.077 , Omega_L = -0.181 , H0 = 0.626
# Good step!
# OmegaM:0.0778 ; OmegaL:-0.1804 ; h:0.624
# Omega_M = 0.078 , Omega_L = -0.18 , H0 = 0.624
# Good step!
# OmegaM:0.0745 ; OmegaL:-0.1784 ; h:0.6401
# Omega_M = 0.075 , Omega_L = -0.178 , H0 = 0.64
# Good step!
# OmegaM:0.0721 ; OmegaL:-0.1781 ; h:0.6544
# Omega_M = 0.072 , Omega_L = -0.178 , H0 = 0.654
# Good step!
# OmegaM:0.0677 ; OmegaL:-0.1843 ; h:0.6391
# Omega_M = 0.068 , Omega_L = -0.184 , H0 = 0.639
# Good step!
# OmegaM:0.0679 ; OmegaL:-0.1795 ; h:0.6314
# Omega_M = 0.068 , Omega_L = -0.18 , H0 = 0.631
# Good step!
# OmegaM:0.0718 ; OmegaL:-0.1857 ; h:0.6538
# Omega_M = 0.072 , Omega_L = -0.186 , H0 = 0.654
# Good step!
# OmegaM:0.059 ; OmegaL:-0.1712 ; h:0.641
# Omega_M = 0.059 , Omega_L = -0.171 , H0 = 0.641
# Good step!
# OmegaM:0.0616 ; OmegaL:-0.1798 ; h:0.6294
# Omega_M = 0.062 , Omega_L = -0.18 , H0 = 0.629
# Good step!
# OmegaM:0.042 ; OmegaL:-0.1583 ; h:0.6324
# Omega_M = 0.042 , Omega_L = -0.158 , H0 = 0.632
# Good step!
# OmegaM:0.0435 ; OmegaL:-0.1604 ; h:0.6267
# Omega_M = 0.044 , Omega_L = -0.16 , H0 = 0.627
# Good step!
# OmegaM:0.0483 ; OmegaL:-0.1608 ; h:0.6457
# Omega_M = 0.048 , Omega_L = -0.161 , H0 = 0.646
# Good step!
# OmegaM:0.042 ; OmegaL:-0.1449 ; h:0.6329
# Omega_M = 0.042 , Omega_L = -0.145 , H0 = 0.633
# Good step!
# OmegaM:0.0379 ; OmegaL:-0.1423 ; h:0.6396
# Omega_M = 0.038 , Omega_L = -0.142 , H0 = 0.64
# Good step!
# OmegaM:0.0306 ; OmegaL:-0.134 ; h:0.6468
# Omega_M = 0.031 , Omega_L = -0.134 , H0 = 0.647
# Good step!
# OmegaM:0.0356 ; OmegaL:-0.1317 ; h:0.6512
# Omega_M = 0.036 , Omega_L = -0.132 , H0 = 0.651
# Good step!
# OmegaM:0.0539 ; OmegaL:-0.1349 ; h:0.6499
# Omega_M = 0.054 , Omega_L = -0.135 , H0 = 0.65
# Good step!
# OmegaM:0.0501 ; OmegaL:-0.1497 ; h:0.6453
# Omega_M = 0.05 , Omega_L = -0.15 , H0 = 0.645
# Good step!
# OmegaM:0.0627 ; OmegaL:-0.1415 ; h:0.632
# Omega_M = 0.063 , Omega_L = -0.142 , H0 = 0.632
# Good step!
# OmegaM:0.0627 ; OmegaL:-0.1308 ; h:0.6518
# Omega_M = 0.063 , Omega_L = -0.131 , H0 = 0.652
# Good step!
# OmegaM:0.0679 ; OmegaL:-0.1327 ; h:0.639
# Omega_M = 0.068 , Omega_L = -0.133 , H0 = 0.639
# Good step!
# OmegaM:0.068 ; OmegaL:-0.1438 ; h:0.6441
# Omega_M = 0.068 , Omega_L = -0.144 , H0 = 0.644
# Good step!
# OmegaM:0.0735 ; OmegaL:-0.1469 ; h:0.6589
# Omega_M = 0.074 , Omega_L = -0.147 , H0 = 0.659
# Good step!
# OmegaM:0.0521 ; OmegaL:-0.1416 ; h:0.6464
# Omega_M = 0.052 , Omega_L = -0.142 , H0 = 0.646
# Good step!
# OmegaM:0.0558 ; OmegaL:-0.1359 ; h:0.6475
# Omega_M = 0.056 , Omega_L = -0.136 , H0 = 0.647
# Good step!
# OmegaM:0.0544 ; OmegaL:-0.128 ; h:0.6515
# Omega_M = 0.054 , Omega_L = -0.128 , H0 = 0.652
# Good step!
# OmegaM:0.0537 ; OmegaL:-0.1322 ; h:0.6464
# Omega_M = 0.054 , Omega_L = -0.132 , H0 = 0.646
# Good step!
# OmegaM:0.0392 ; OmegaL:-0.1294 ; h:0.6529
# Omega_M = 0.039 , Omega_L = -0.129 , H0 = 0.653
# Good step!
# OmegaM:0.018 ; OmegaL:-0.138 ; h:0.6409
# Omega_M = 0.018 , Omega_L = -0.138 , H0 = 0.641
# Good step!
# OmegaM:0.0195 ; OmegaL:-0.1314 ; h:0.6483
# Omega_M = 0.02 , Omega_L = -0.131 , H0 = 0.648
# Good step!
# OmegaM:0.0181 ; OmegaL:-0.1207 ; h:0.6509
# Omega_M = 0.018 , Omega_L = -0.121 , H0 = 0.651
# Good step!
# OmegaM:0.0159 ; OmegaL:-0.1124 ; h:0.6557
# Omega_M = 0.016 , Omega_L = -0.112 , H0 = 0.656
# Good step!
# OmegaM:0.022 ; OmegaL:-0.0947 ; h:0.6695
# Omega_M = 0.022 , Omega_L = -0.095 , H0 = 0.669
# Good step!
# OmegaM:0.0039 ; OmegaL:-0.096 ; h:0.6654
# Omega_M = 0.004 , Omega_L = -0.096 , H0 = 0.665
# Good step!
# OmegaM:0.0047 ; OmegaL:-0.1011 ; h:0.6699
# Omega_M = 0.005 , Omega_L = -0.101 , H0 = 0.67
# Good step!
# OmegaM:0.0057 ; OmegaL:-0.1009 ; h:0.6922
# Omega_M = 0.006 , Omega_L = -0.101 , H0 = 0.692
# Good step!
# OmegaM:-0.0013 ; OmegaL:-0.0904 ; h:0.6979
# Omega_M = -0.001 , Omega_L = -0.09 , H0 = 0.698
# Good step!
# OmegaM:0.0019 ; OmegaL:-0.0869 ; h:0.7069
# Omega_M = 0.002 , Omega_L = -0.087 , H0 = 0.707
# Good step!
# OmegaM:0.0009 ; OmegaL:-0.0806 ; h:0.7044
# Omega_M = 0.001 , Omega_L = -0.081 , H0 = 0.704
# Good step!
# OmegaM:0.0119 ; OmegaL:-0.0855 ; h:0.7154
# Omega_M = 0.012 , Omega_L = -0.085 , H0 = 0.715
# Good step!
# OmegaM:0.0082 ; OmegaL:-0.1031 ; h:0.704
# Omega_M = 0.008 , Omega_L = -0.103 , H0 = 0.704
# Good step!
# OmegaM:0.002 ; OmegaL:-0.1086 ; h:0.7072
# Omega_M = 0.002 , Omega_L = -0.109 , H0 = 0.707
# Good step!
# OmegaM:0.0066 ; OmegaL:-0.1094 ; h:0.7115
# Omega_M = 0.007 , Omega_L = -0.109 , H0 = 0.712
# Good step!
# OmegaM:0.0206 ; OmegaL:-0.1223 ; h:0.7037
# Omega_M = 0.021 , Omega_L = -0.122 , H0 = 0.704
# Good step!
# OmegaM:0.0252 ; OmegaL:-0.1253 ; h:0.7015
# Omega_M = 0.025 , Omega_L = -0.125 , H0 = 0.701
# Good step!
# OmegaM:0.0268 ; OmegaL:-0.1262 ; h:0.6939
# Omega_M = 0.027 , Omega_L = -0.126 , H0 = 0.694
# Good step!
# OmegaM:0.03 ; OmegaL:-0.1303 ; h:0.6886
# Omega_M = 0.03 , Omega_L = -0.13 , H0 = 0.689
# Good step!
# OmegaM:0.0202 ; OmegaL:-0.1283 ; h:0.678
# Omega_M = 0.02 , Omega_L = -0.128 , H0 = 0.678
# Good step!
# OmegaM:0.0145 ; OmegaL:-0.1395 ; h:0.6833
# Omega_M = 0.015 , Omega_L = -0.14 , H0 = 0.683
# Good step!
# OmegaM:0.0057 ; OmegaL:-0.131 ; h:0.6836
# Omega_M = 0.006 , Omega_L = -0.131 , H0 = 0.684
# Good step!
# OmegaM:-0.0008 ; OmegaL:-0.1221 ; h:0.6818
# Omega_M = -0.001 , Omega_L = -0.122 , H0 = 0.682
# Good step!
# OmegaM:0.0031 ; OmegaL:-0.1269 ; h:0.6792
# Omega_M = 0.003 , Omega_L = -0.127 , H0 = 0.679
# Good step!
# OmegaM:-0.0018 ; OmegaL:-0.1344 ; h:0.6718
# Omega_M = -0.002 , Omega_L = -0.134 , H0 = 0.672
# Good step!
# OmegaM:-0.0105 ; OmegaL:-0.1308 ; h:0.672
# Omega_M = -0.011 , Omega_L = -0.131 , H0 = 0.672
# Good step!
# OmegaM:-0.0116 ; OmegaL:-0.131 ; h:0.6706
# Omega_M = -0.012 , Omega_L = -0.131 , H0 = 0.671
# Good step!
# OmegaM:-0.022 ; OmegaL:-0.1593 ; h:0.6728
# Omega_M = -0.022 , Omega_L = -0.159 , H0 = 0.673
# Good step!
# OmegaM:-0.0176 ; OmegaL:-0.1545 ; h:0.6966

# %%
plt.errorbar(zs, distance_modulus,\
             yerr=error_distance_modulus,\
             fmt='o',\
             color='black',\
             ecolor='red',\
             markersize=2)

modelzs = np.arange(0.05, 1.5, 0.05)
modelmus = []
for z in modelzs :
    modelmus += [mu(z, Omega_L_old, Omega_M_old, H0_old)]

plt.plot(modelzs, modelmus, linewidth=4)
plt.show()

# %% [markdown]
# After completion of the programme, your MC chain will (*hopefully*) look something like this: (note the repeated entry!)
#
# `#Omega_m  Omega_L  h`
#
# `0.297     0.703    0.698`
#
# `0.285     0.715    0.701`
#
# `0.285     0.715    0.701`
#
# `0.288     0.712    0.699`
#
# `...`

# %% [markdown]
# ## <font color='deepskyblue'>Plotting: GetDist</font>
#
# We will do the plots with [`GetDist`](https://getdist.readthedocs.io/en/latest/plot_gallery.html).
#
# The plot gallery contains a lot of useful examples, you should be able to read them fairly easily and see which applies to your situation. Look for both (triangle) plots and for parameter estimation.
#
# Note that many `GetDist` functions require arguments of type `MCSamples`; make sure you convert your lists accordingly.
#
# <font color='deepskyblue'>
# Look at your results. Do you obtain $\Omega_\Lambda \neq 0$? To a high degree of significance?
#
# If yes, then my dear friend, you have **DISCOVERED THE ACCELERATED EXPANSION OF THE UNIVERSE AND WON THE NOBEL PRIZE IN PHYSICS 2011!**
# </font>

# %%
import numpy as np
from getdist import MCSamples, plots

Omega_K_list = []
for Omega_M_old, Omega_L_old in zip(Omega_M_list, Omega_L_list):
  Omega_K = 1 - Omega_M_old - Omega_L_old
  Omega_K_list.append(Omega_K)

# Let's define variable names and labels
my_labels = [r'H0', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_k']
my_names = ['H0', 'Omega_M', 'Omega_L', 'Omega_K']
my_dim = len(my_names) # The number of variables we're plotting

# This creates a higher-dimensional array with all our data, shaped in the appropriate way...
parameters_val = [H0_list, Omega_L_list, Omega_M_list, Omega_K_list]
my_samples_arr = np.array(parameters_val)
my_samples = np.transpose(my_samples_arr)

# ... to create an "MCSamples" data type, which GetDist can use
my_samples1 = MCSamples(samples = my_samples, labels = my_labels, names = my_names)

burn_in = 900
my_samples1.removeBurn(burn_in)

# The usual 1-sigma confidence level. You can change to 2- or 3-sigma if you want
conf_level = 0.6827

# This prints a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(my_samples1.confidence(nam,(1.-conf_level)/2.,upper=False),2), \
          " < ", nam , " < ", round(my_samples1.confidence(nam,(1.-conf_level)/2.,upper=True),2),\
          " at " , int(100*conf_level),"\b% CL")
print("\n")

#Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16

contour_colors = ['purple', 'green', 'blue', 'red']
j.triangle_plot(my_samples1, filled=True, title_limit=1, contour_colors=contour_colors)

# Showing the plot
plt.show()
# Out:
# Removed no burn in
# % CL
# % CL
# % CL
# % CL
# WARNING:root:Parameters are 100% correlated: Omega_M, Omega_L
# WARNING:root:Parameters are 100% correlated: Omega_M, Omega_K
# WARNING:root:Parameters are 100% correlated: Omega_L, Omega_K

# %%
# I tried to monitor acceptance ratio and 𝜒2 as a function of step count, but I think I messed up along the way
import numpy as np

N_steps = 5000
Omega_M_old = 0.1
Omega_L_old = 0.1
H0_old = 0.1
acceptance_count = 0
chiSquared_list = []
acceptance_ratio_list = []

for i in range(N_steps):
  chi_squared_old = chi_squared(Omega_L_old, Omega_M_old, H0_old)
  Omega_M_new = Omega_M_old + np.random.normal(0,0.01)
  Omega_L_new = Omega_L_old + np.random.normal(0,0.01)
  H0_new = H0_old + np.random.normal(0,0.01)
  chi_squared_new = chi_squared(Omega_L_new, Omega_M_new, H0_new)

  # Calculating the acceptance probability using the exponential to check if the value is between 0 and 1;
  # if it is, then the chain is acceptable
  acceptance_prob = min(1, np.exp((chi_squared_old - chi_squared_new) / 2.0))

if chi_squared_new < chi_squared_old or np.random.uniform(0, 1) < acceptance_prob:
  Omega_M_old = Omega_M_new
  Omega_L_old = Omega_L_new
  H0_old = H0_new
  chi_squared_old = chi_squared_new
  acceptance_count += 1

  # Storing the chi-squared and the acceptance ratio
  chiSquared_list.append(chi_squared_old)
  acceptance_ratio_list.append(acceptance_count / (i + 1))

# Printing the average of both
print("Mean acceptance ratio:", np.mean(acceptance_ratio_list))
print("Mean chi-squared:", np.mean(chiSquared_list))
# Out:
# <ipython-input-127-7a7ef366bec8>:20: RuntimeWarning: overflow encountered in exp
#   acceptance_prob = min(1, np.exp((chi_squared_old - chi_squared_new) / 2.0))
# Mean acceptance ratio: 0.0002
# Mean chi-squared: 269770.7942120209

# %% [markdown]
# ## <font color='deepskyblue'>Further Improvements</font>
#
# There are many ways in which you can improve your code and/or your data visualisation. Some ideas, in random order:
#
# * Modify your priors and compare your results. For instance:
#   * Change to log-flat priors for $h$ and/or $\Omega_m$, namely displace them in log-space instead of linear space:
#   $$
#   \log(h_{\rm new}) = \log(h_{\rm old}) + \delta
#   $$
#   where $\delta$ a random variable of mean 0
#   * Use priors from other cosmological probes, for example the [Planck 2018 results](https://arxiv.org/abs/1807.06209):
#   $$
#   \Omega_m = 0.315 \pm 0.007\,,~\dots
#   $$
# * Monitor acceptance ratio and $\chi^2$ as a function of step count
# * Implement a Gelman-Rubin (or alternative) convergence test
# * Change colours and other properties of your triangle plot
# * Re-plot the data with your theoretical fits: you can try both your best fit, and some $1\sigma$ "error bars"
# * Split your data in redshift bins and repeat the analysis for each bin individually.
# <br> _(What do you notice? Which redshift bins give us the most accurate detection of the cosmological parameters?)_
